# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #CONVERTING TO PNG FORMAT

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.8 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
import os
import pydicom
import numpy as np
from PIL import Image

# Test Images
def convert_dicom_to_png(input_root):
    """
    Converts all DICOM slices to PNGs and saves them in a 'converted_png'
    folder inside each CT scan folder, alongside 'DICOM_anon' and 'Ground'.
    """
    ct_scan_folders = os.listdir(input_root)

    for ct_scan in ct_scan_folders:
        ct_scan_path = os.path.join(input_root, ct_scan)
        if not os.path.isdir(ct_scan_path):
            continue

        dicom_input_folder = os.path.join(ct_scan_path, 'DICOM_anon')
        png_output_folder = os.path.join(ct_scan_path, 'converted_png')
        os.makedirs(png_output_folder, exist_ok=True)

        if not os.path.isdir(dicom_input_folder):
            print(f"[Skipping] No DICOM_anon in {ct_scan}")
            continue

        dicom_files = [f for f in os.listdir(dicom_input_folder) if f.lower().endswith('.dcm')]

        for dicom_file in dicom_files:
            dicom_path = os.path.join(dicom_input_folder, dicom_file)
            try:
                ds = pydicom.dcmread(dicom_path)
                img_array = ds.pixel_array.astype(float)
                img_array = (np.maximum(img_array, 0) / img_array.max()) * 255.0
                img_array = img_array.astype(np.uint8)
                img = Image.fromarray(img_array)
                slice_num = ds.get('InstanceNumber', dicom_files.index(dicom_file) + 1)
                out_filename = f"slice_{slice_num:03d}.png"
                out_path = os.path.join(png_output_folder, out_filename)
                img.save(out_path)
                print(f"[OK] {dicom_path} -> {out_path}")
            except Exception as e:
                print(f"[Error] {dicom_path}: {e}")

if __name__ == "__main__":
    input_root = "/content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT" # adjust as needed
    convert_dicom_to_png(input_root)
# Out:
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0015,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0008,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0095,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_096.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0094,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_095.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0085,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_086.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0091,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_092.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0096,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_097.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0086,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_087.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0083,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_084.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0087,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_088.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0084,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_085.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0092,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_093.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0088,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_089.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0093,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_094.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0090,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_091.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/DICOM_anon/i0089,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/9/converted_png/slice_090.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0015,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0008,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0091,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_092.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0088,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_089.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0084,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_085.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0094,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_095.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0087,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_088.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0093,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_094.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0085,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_086.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0089,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_090.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0086,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_087.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0092,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_093.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0090,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_091.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0083,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_084.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0099,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_100.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0097,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_098.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0104,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_105.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0101,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_102.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0102,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_103.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0098,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_099.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0096,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_097.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0105,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_106.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0103,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_104.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0095,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_096.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0106,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_107.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0107,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_108.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/DICOM_anon/i0100,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/7/converted_png/slice_101.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00007.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00017.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00002.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00016.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00018.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00015.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00021.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00022.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00012.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00020.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00001.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00025.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00008.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00010.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00026.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00003.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00006.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00009.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00023.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00014.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00027.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00028.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00005.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00019.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00024.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00004.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00011.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00013.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00038.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00059.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00035.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00037.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00033.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00029.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00032.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00054.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00045.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00030.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00056.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00046.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00052.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00041.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00042.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00055.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/DICOM_anon/IMG-0012-00036.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/40/converted_png/slice_036.png
# ...
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0015,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Test_Sets/Test_Sets/CT/11/converted_png/slice_059.png

# %%
import os
import pydicom
import numpy as np
from PIL import Image

# Train Images
def convert_dicom_to_png(input_root):
    """
    Converts all DICOM slices to PNGs and saves them in a 'converted_png'
    folder inside each CT scan folder, alongside 'DICOM_anon' and 'Ground'.
    """
    ct_scan_folders = os.listdir(input_root)

    for ct_scan in ct_scan_folders:
        ct_scan_path = os.path.join(input_root, ct_scan)
        if not os.path.isdir(ct_scan_path):
            continue

        dicom_input_folder = os.path.join(ct_scan_path, 'DICOM_anon')
        png_output_folder = os.path.join(ct_scan_path, 'converted_png')
        os.makedirs(png_output_folder, exist_ok=True)

        if not os.path.isdir(dicom_input_folder):
            print(f"[Skipping] No DICOM_anon in {ct_scan}")
            continue

        dicom_files = [f for f in os.listdir(dicom_input_folder) if f.lower().endswith('.dcm')]

        for dicom_file in dicom_files:
            dicom_path = os.path.join(dicom_input_folder, dicom_file)
            try:
                ds = pydicom.dcmread(dicom_path)
                img_array = ds.pixel_array.astype(float)
                img_array = (np.maximum(img_array, 0) / img_array.max()) * 255.0
                img_array = img_array.astype(np.uint8)
                img = Image.fromarray(img_array)
                slice_num = ds.get('InstanceNumber', dicom_files.index(dicom_file) + 1)
                out_filename = f"slice_{slice_num:03d}.png"
                out_path = os.path.join(png_output_folder, out_filename)
                img.save(out_path)
                print(f"[OK] {dicom_path} -> {out_path}")
            except Exception as e:
                print(f"[Error] {dicom_path}: {e}")

if __name__ == "__main__":
    input_root = "/content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT" # adjust as needed
    convert_dicom_to_png(input_root)
# Out:
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0008,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0015,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0091,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_092.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0084,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_085.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0094,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_095.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0093,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_094.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0085,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_086.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0090,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_091.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0088,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_089.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0083,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_084.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0089,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_090.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0092,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_093.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0086,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_087.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/DICOM_anon/i0087,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/5/converted_png/slice_088.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0008,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0015,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_016.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0091,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_092.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0094,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_095.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0090,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_091.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0089,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_090.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0084,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_085.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0083,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_084.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0086,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_087.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0087,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_088.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0093,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_094.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0092,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_093.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0088,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_089.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0095,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_096.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0085,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_086.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0096,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_097.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0121,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_122.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0112,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_113.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0106,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_107.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0113,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_114.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0104,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_105.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0109,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_110.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0120,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_121.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0115,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_116.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0101,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_102.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0108,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_109.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0105,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_106.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0098,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_099.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0111,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_112.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0107,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_108.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0117,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_118.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0122,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_123.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0110,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_111.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0097,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_098.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0103,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_104.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0100,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_101.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0099,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_100.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0118,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_119.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0116,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_117.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0119,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_120.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0102,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_103.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/DICOM_anon/i0114,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/8/converted_png/slice_115.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0011,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_012.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0008,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_009.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0003,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_004.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0006,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_007.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0005,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_006.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0007,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_008.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0010,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_011.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0002,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_003.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0014,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_015.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0012,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_013.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0013,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_014.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0004,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_005.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0001,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_002.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/6/converted_png/slice_038.png
# ...
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0000,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_001.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0009,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_010.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0035,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_036.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0043,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_044.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0029,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_030.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0040,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_041.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0022,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_023.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0042,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_043.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0018,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_019.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0033,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_034.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0030,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_031.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0039,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_040.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0036,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_037.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0031,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_032.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0044,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_045.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0028,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_029.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0016,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_017.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0027,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_028.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0045,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_046.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0032,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_033.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0026,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_027.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0019,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_020.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0037,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_038.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0034,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_035.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0047,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_048.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0025,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_026.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0017,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_018.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0021,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_022.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0038,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_039.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0023,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_024.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0046,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_047.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0020,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_021.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0041,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_042.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0024,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_025.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0073,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_074.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0063,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_064.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0058,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_059.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0071,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_072.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0065,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_066.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0068,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_069.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0067,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_068.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0066,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_067.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0055,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_056.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0072,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_073.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0059,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_060.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0061,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_062.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0069,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_070.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0057,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_058.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0051,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_052.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0052,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_053.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0050,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_051.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0056,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_057.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0074,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_075.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0075,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_076.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0062,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_063.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0060,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_061.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0070,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_071.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0053,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_054.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0048,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_049.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0049,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_050.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0064,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_065.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0054,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_055.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0091,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_092.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0076,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_077.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0077,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_078.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0081,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_082.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0093,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_094.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0085,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_086.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0086,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_087.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0095,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_096.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0089,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_090.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0078,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_079.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0084,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_085.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0082,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_083.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0092,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_093.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0088,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_089.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0087,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_088.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0079,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_080.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0083,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_084.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0090,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_091.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0080,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_081.png
# [OK] /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/DICOM_anon/i0094,0000b.dcm -> /content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT/1/converted_png/slice_095.png

# %%
import os
import numpy as np
from PIL import Image

def crop_liver_from_mask(image, mask):
    mask_np = np.array(mask)
    coords = np.argwhere(mask_np)
    if coords.size == 0:
        return None, None
    y0, x0 = coords.min(axis=0)
    y1, x1 = coords.max(axis=0) + 1
    cropped_img = image.crop((x0, y0, x1, y1))
    cropped_mask = mask.crop((x0, y0, x1, y1))
    return cropped_img, cropped_mask

def preprocess_diffusion_images_and_masks_flat(
    root_folder, output_folder_img, output_folder_mask, target_size=(256,256)
):
    ct_scan_folders = sorted(os.listdir(root_folder))
    os.makedirs(output_folder_img, exist_ok=True)
    os.makedirs(output_folder_mask, exist_ok=True)
    img_counter = 0

    for ct_scan in ct_scan_folders:
        ct_scan_path = os.path.join(root_folder, ct_scan)
        if not os.path.isdir(ct_scan_path):
            continue

        converted_png_folder = os.path.join(ct_scan_path, "converted_png")
        mask_folder = os.path.join(ct_scan_path, "Ground")

        images = sorted([f for f in os.listdir(converted_png_folder) if f.endswith('.png')])
        masks = sorted([f for f in os.listdir(mask_folder) if f.endswith('.png')])

        images = images[:len(masks)]

        for idx, (img_file, mask_file) in enumerate(zip(images, masks)):
            img_path = os.path.join(converted_png_folder, img_file)
            mask_path = os.path.join(mask_folder, mask_file)
            img = Image.open(img_path).convert("L")
            mask = Image.open(mask_path).convert("L")

            cropped_img, cropped_mask = crop_liver_from_mask(img, mask)
            if cropped_img is None:
                print(f"Skipping {img_file}: empty mask")
                continue

            # Resize both image and mask
            resized_img = cropped_img.resize(target_size, Image.BILINEAR)
            resized_mask = cropped_mask.resize(target_size, Image.NEAREST)  # NEAREST for masks to preserve labels

            # Normalize image to [0,1]
            img_np = np.array(resized_img).astype(np.float32) / 255.0
            normalized_img = Image.fromarray((img_np * 255).astype(np.uint8))

            # Save both image and mask
            save_img_path = os.path.join(output_folder_img, f"pre_liver_{img_counter:05d}.png")
            save_mask_path = os.path.join(output_folder_mask, f"pre_mask_{img_counter:05d}.png")
            normalized_img.save(save_img_path)
            resized_mask.save(save_mask_path)
            img_counter += 1
            print(f"Saved: {save_img_path}  |  {save_mask_path}")

if __name__ == "__main__":
    root = "/content/drive/MyDrive/dataset-1/CHAOS_Train_Sets/Train_Sets/CT"
    output_img = "/content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img"
    output_mask = "/content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask"
    preprocess_diffusion_images_and_masks_flat(root, output_img, output_mask, target_size=(256,256))
# Out:
# Skipping slice_001.png: empty mask
# Skipping slice_002.png: empty mask
# Skipping slice_003.png: empty mask
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00000.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00000.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00001.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00001.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00002.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00002.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00003.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00003.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00004.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00004.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00005.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00005.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00006.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00006.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00007.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00007.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00008.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00008.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00009.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00009.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00010.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00010.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00011.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00011.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00012.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00012.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00013.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00013.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00014.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00014.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00015.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00015.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00016.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00016.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00017.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00017.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00018.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00018.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00019.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00019.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00020.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00020.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00021.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00021.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00022.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00022.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00023.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00023.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00024.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00024.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00025.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00025.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00026.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00026.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00027.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00027.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00028.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00028.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00029.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00029.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00030.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00030.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00031.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00031.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00032.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00032.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00033.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00033.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00034.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00034.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00035.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00035.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00036.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00036.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00037.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00037.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00038.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00038.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00039.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00039.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00040.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00040.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00041.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00041.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00042.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00042.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00043.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00043.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00044.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00044.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00045.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00045.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00046.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00046.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00047.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00047.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00048.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00048.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00049.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00049.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00050.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00050.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00051.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00051.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00052.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00052.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00053.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00053.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00054.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00054.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00055.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00055.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00056.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00056.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00057.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00057.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00058.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00058.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00059.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00059.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00060.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00060.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00061.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00061.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00062.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00062.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00063.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00063.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00064.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00064.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00065.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00065.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00066.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00066.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00067.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00067.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00068.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00068.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00069.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00069.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00070.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00070.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00071.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00071.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00072.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00072.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00073.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00073.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00074.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00074.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00075.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00075.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00076.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00076.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00077.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00077.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00078.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00078.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00079.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00079.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00080.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00080.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00081.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00081.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00082.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00082.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00083.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00083.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00084.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00084.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00085.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00085.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00086.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00086.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00087.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00087.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00088.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00088.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00089.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00089.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00090.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00090.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00091.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00091.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00092.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00092.png
# Skipping slice_001.png: empty mask
# Skipping slice_002.png: empty mask
# Skipping slice_003.png: empty mask
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00093.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00093.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00094.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00094.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00095.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00095.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00096.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00096.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00097.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00097.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00098.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00098.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00099.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00099.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00100.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00100.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00101.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00101.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00102.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00102.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00103.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00103.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00104.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00104.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00105.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00105.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00106.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00106.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00107.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00107.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00108.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00108.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00109.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00109.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00110.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00110.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00111.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00111.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00112.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00112.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00113.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00113.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00114.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00114.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00115.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00115.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00116.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00116.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00117.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00117.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00118.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00118.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00119.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00119.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00120.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00120.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00121.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00121.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00122.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00122.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00123.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00123.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00124.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00124.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00125.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00125.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00126.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00126.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00127.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00127.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00128.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00128.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00129.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00129.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00130.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00130.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00131.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00131.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00132.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00132.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00133.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00133.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00134.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00134.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00135.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00135.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00136.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00136.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00137.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00137.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00138.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00138.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00139.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00139.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00140.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00140.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00141.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00141.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00142.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00142.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00143.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00143.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00144.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00144.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00145.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00145.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00146.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00146.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00147.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00147.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00148.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00148.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00149.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00149.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00150.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00150.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00151.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00151.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00152.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00152.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00153.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00153.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00154.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00154.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00155.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00155.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00156.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00156.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00157.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00157.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00158.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00158.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00159.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00159.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00160.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00160.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00161.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00161.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00162.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00162.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00163.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00163.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00164.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00164.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00165.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00165.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00166.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00166.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00167.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00167.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00168.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00168.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00169.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00169.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00170.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00170.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00171.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00171.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00172.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00172.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00173.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00173.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00174.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00174.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00175.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00175.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00176.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00176.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00177.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00177.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00178.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00178.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00179.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00179.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00180.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00180.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00181.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00181.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00182.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00182.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00183.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00183.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00184.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00184.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00185.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00185.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00186.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00186.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00187.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00187.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00188.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00188.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00189.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00189.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00190.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00190.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00191.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00191.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00192.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00192.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00193.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00193.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00194.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00194.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00195.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00195.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00196.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00196.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00197.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00197.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00198.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00198.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00199.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00199.png
# Skipping slice_001.png: empty mask
# Skipping slice_002.png: empty mask
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00200.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00200.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00201.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00201.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00202.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00202.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00203.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00203.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00204.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00204.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00205.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00205.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00206.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00206.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00207.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00207.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00208.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00208.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00209.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00209.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00210.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00210.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00211.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00211.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00212.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00212.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00213.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00213.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00214.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00214.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00215.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00215.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00216.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00216.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00217.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00217.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00218.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00218.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00219.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00219.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00220.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00220.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00221.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00221.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00222.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00222.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00223.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00223.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00224.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00224.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00225.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00225.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00226.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00226.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00227.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00227.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00228.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00228.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00229.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00229.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00230.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00230.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00231.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00231.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00232.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00232.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00233.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00233.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00234.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00234.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00235.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00235.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00236.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00236.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00237.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00237.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00238.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00238.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00239.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00239.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00240.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00240.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00241.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00241.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00242.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00242.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00243.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00243.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00244.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00244.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00245.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00245.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00246.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00246.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00247.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00247.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00248.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00248.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00249.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00249.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00250.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00250.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00251.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00251.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00252.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00252.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00253.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00253.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00254.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00254.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00255.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00255.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00256.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00256.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00257.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00257.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00258.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00258.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_00259.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_00259.png
# ...
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02266.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02266.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02267.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02267.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02268.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02268.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02269.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02269.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02270.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02270.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02271.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02271.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02272.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02272.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02273.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02273.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02274.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02274.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02275.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02275.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02276.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02276.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02277.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02277.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02278.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02278.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02279.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02279.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02280.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02280.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02281.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02281.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02282.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02282.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02283.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02283.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02284.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02284.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02285.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02285.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02286.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02286.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02287.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02287.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02288.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02288.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02289.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02289.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02290.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02290.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02291.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02291.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02292.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02292.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02293.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02293.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02294.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02294.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02295.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02295.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02296.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02296.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02297.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02297.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02298.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02298.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02299.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02299.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02300.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02300.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02301.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02301.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02302.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02302.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02303.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02303.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02304.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02304.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02305.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02305.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02306.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02306.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02307.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02307.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02308.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02308.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02309.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02309.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02310.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02310.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02311.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02311.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02312.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02312.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02313.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02313.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02314.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02314.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02315.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02315.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02316.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02316.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02317.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02317.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02318.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02318.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02319.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02319.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02320.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02320.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02321.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02321.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02322.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02322.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02323.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02323.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02324.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02324.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02325.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02325.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02326.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02326.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02327.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02327.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02328.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02328.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02329.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02329.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02330.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02330.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02331.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02331.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02332.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02332.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02333.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02333.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02334.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02334.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02335.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02335.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02336.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02336.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02337.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02337.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02338.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02338.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02339.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02339.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02340.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02340.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02341.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02341.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02342.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02342.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02343.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02343.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02344.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02344.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02345.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02345.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02346.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02346.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02347.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02347.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02348.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02348.png
# Saved: /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_img/pre_liver_02349.png  |  /content/drive/MyDrive/dataset-1/preprocessed_diffusion_input_mask/pre_mask_02349.png
# Skipping slice_109.png: empty mask
# Skipping slice_110.png: empty mask
# Skipping slice_111.png: empty mask
# Skipping slice_112.png: empty mask
# Skipping slice_113.png: empty mask
# Skipping slice_114.png: empty mask
# Skipping slice_115.png: empty mask
# Skipping slice_116.png: empty mask
# Skipping slice_117.png: empty mask
# Skipping slice_118.png: empty mask
# Skipping slice_119.png: empty mask
# Skipping slice_120.png: empty mask
# Skipping slice_121.png: empty mask
# Skipping slice_122.png: empty mask
# Skipping slice_123.png: empty mask

# %%
import google
from google.colab import drive

# Mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Extract ZIP file to a folder
zip_path = '/content/drive/MyDrive/hack4health/diffusion_3_preprocessed.zip'
extract_folder = 'extracted_numpy_data'  # Name of folder to create

if zip_path.endswith('.zip') and zipfile.is_zipfile(zip_path):
    print(f"Extracting {zip_path} to {extract_folder}...")

    # Create extraction folder if it doesn't exist
    os.makedirs(extract_folder, exist_ok=True)

    # Extract all contents
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)

    print(f"✅ Extraction complete! Files extracted to: {extract_folder}")

    # Update folder_path to point to extracted folder
    folder_path = extract_folder
else:
    # If not a ZIP file, use as-is
    folder_path = zip_path

# Now use the extracted folder with your dataset
# Out:
# Extracting /content/drive/MyDrive/hack4health/diffusion_3_preprocessed.zip to extracted_numpy_data...
# ✅ Extraction complete! Files extracted to: extracted_numpy_data

# %%
import os
import shutil

# Root directory where your data is stored
root_dir = "/content/extracted_numpy_data/diffusion_3_preprocessed"
output_dir = "/content/all_images_only"

# Create the output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Walk through each patient folder
for patient_folder in os.listdir(root_dir):
    patient_path = os.path.join(root_dir, patient_folder)
    images_path = os.path.join(patient_path, "images")

    # Check if "images" folder exists for the patient
    if os.path.isdir(images_path):
        for file in os.listdir(images_path):
            if file.endswith(".npy"):
                src = os.path.join(images_path, file)

                # Add patient name to filename to avoid overwriting
                dst = os.path.join(output_dir, f"{patient_folder}_{file}")
                shutil.copy(src, dst)

print("✅ All .npy files from 'images' folders copied to:", output_dir)
# Out:
# ✅ All .npy files from 'images' folders copied to: /content/all_images_only

# %%
import shutil

# Path to your Drive (mounted earlier)
drive_path = "/content/drive/MyDrive"

# Source (the new folder you created)
src_folder = "/content/all_images_only"

# Destination (inside your Drive)
dst_folder = os.path.join(drive_path, "all_images_only")

# Copy the folder to Drive
shutil.copytree(src_folder, dst_folder, dirs_exist_ok=True)

print("✅ Folder uploaded to Drive at:", dst_folder)
# Out:
# ✅ Folder uploaded to Drive at: /content/drive/MyDrive/all_images_only

# %%
import os

folder = "/content/all_images_only"

# Count only files (ignore subfolders, if any)
num_files = len([f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))])

print("Number of files in folder:", num_files)
# Out:
# Number of files in folder: 2341

# %%
# @title DIFFUSION MODEL ,DDPM
#diffusion model
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True):
        """
        Args:
            folder_path: Path to folder containing .npy files
            augment: Whether to apply data augmentation
        """
        print(f"Loading numpy files from folder: {folder_path}")

        # Find all .npy files in the folder
        npy_files = glob.glob(os.path.join(folder_path, "*.npy"))

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")

        # Load and concatenate all numpy arrays
        all_images = []
        for npy_file in tqdm(npy_files, desc="Loading .npy files"):
            images = np.load(npy_file)
            print(f"Loaded {npy_file}: shape {images.shape}")

            # Handle different shapes
            if len(images.shape) == 2:  # Single image (H, W)
                images = images[None, :, :]  # Add batch dimension -> (1, H, W)
            elif len(images.shape) == 3:  # Could be (N, H, W) or (H, W, C)
                if images.shape[-1] == 1 or images.shape[-1] == 3:  # (H, W, C)
                    images = images[None, :, :, :]  # Add batch dimension -> (1, H, W, C)

            all_images.append(images)

        # Concatenate all images
        self.images = np.concatenate(all_images, axis=0)

        print(f"Combined dataset: {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")

        # Normalize images to [0, 1] if not already normalized
        if self.images.max() > 1.0:
            print("Normalizing images from [0, 255] to [0, 1]")
            self.images = self.images.astype(np.float32) / 255.0
        else:
            self.images = self.images.astype(np.float32)

        # Ensure images have the right dimensions for grayscale
        if len(self.images.shape) == 3:  # (N, H, W)
            print("Adding channel dimension for grayscale")
            self.images = self.images[:, None, :, :]  # (N, 1, H, W)
        elif len(self.images.shape) == 4:
            if self.images.shape[-1] == 1:  # (N, H, W, 1) -> (N, 1, H, W)
                print("Converting from (N, H, W, 1) to (N, 1, H, W)")
                self.images = np.transpose(self.images, (0, 3, 1, 2))
            elif self.images.shape[1] != 1 and self.images.shape[1] != 3:  # (N, H, W, C) format
                print("Converting from (N, H, W, C) to (N, C, H, W)")
                self.images = np.transpose(self.images, (0, 3, 1, 2))

        print(f"Final image shape: {self.images.shape}")

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()  # (1, H, W) or (C, H, W)

        # Ensure image is (1, H, W) for grayscale
        if len(image.shape) == 2:
            image = image[None, :, :]
        elif len(image.shape) == 3 and image.shape[0] != 1:
            # If it's RGB, convert to grayscale
            if image.shape[0] == 3:
                image = np.mean(image, axis=0, keepdims=True)

        # Convert to tensor
        image = torch.from_numpy(image).float()

        # Apply augmentation
        if self.augment and np.random.random() > 0.5:
            # Random horizontal flip
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

            # Random vertical flip (careful with CT scans - may not be appropriate)
            # if np.random.random() > 0.7:
            #     image = torch.flip(image, [1])

        # Normalize to [-1, 1] for diffusion training
        image = image * 2.0 - 1.0

        return image

# Alternative: Single file dataset (your original code)
class SingleNumpyDataset(Dataset):
    def __init__(self, numpy_file_path, augment=True):
        """
        For when you have a single .npy file containing all images
        Args:
            numpy_file_path: Path to single .npy file containing images
            augment: Whether to apply data augmentation
        """
        print(f"Loading numpy array from single file: {numpy_file_path}")

        # Load numpy array
        self.images = np.load(numpy_file_path)

        print(f"Loaded {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")

        # Normalize images to [0, 1] if not already normalized
        if self.images.max() > 1.0:
            print("Normalizing images from [0, 255] to [0, 1]")
            self.images = self.images.astype(np.float32) / 255.0
        else:
            self.images = self.images.astype(np.float32)

        # Ensure images have the right dimensions
        if len(self.images.shape) == 3:  # (N, H, W)
            print("Adding channel dimension")
            self.images = self.images[:, None, :, :]  # (N, 1, H, W)
        elif len(self.images.shape) == 4 and self.images.shape[-1] == 1:  # (N, H, W, 1)
            print("Converting from (N, H, W, 1) to (N, 1, H, W)")
            self.images = np.transpose(self.images, (0, 3, 1, 2))

        print(f"Final image shape: {self.images.shape}")

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()  # (1, H, W) or (H, W)

        # Ensure image is (1, H, W)
        if len(image.shape) == 2:
            image = image[None, :, :]

        # Convert to tensor
        image = torch.from_numpy(image).float()

        # Apply augmentation
        if self.augment and np.random.random() > 0.5:
            # Random horizontal flip
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        # Normalize to [-1, 1] for diffusion training
        image = image * 2.0 - 1.0

        return image

# Choose the appropriate dataset based on your setup
folder_path = '/content/all_images_only'  # Folder containing multiple .npy files

# OPTION 1: If you have multiple .npy files in a folder (your case)
train_dataset = MultipleNumpyDataset(folder_path, augment=True)

# OPTION 2: If you have a single .npy file containing all images
# single_file_path = 'path/to/your/single/file.npy'
# train_dataset = SingleNumpyDataset(single_file_path, augment=True)

# Rest of your training code remains the same...
train_dataloader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

print(f"Dataset size: {len(train_dataset)}")
print(f"Number of batches per epoch: {len(train_dataloader)}")

# The rest of your training code continues unchanged...
# Out:
# Using device: cuda
# Loading numpy files from folder: /content/all_images_only
# Found 2341 .npy files
# Loading .npy files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Loaded /content/all_images_only/patient_16_16_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0074.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0172.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0091.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0060.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0163.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0054.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0022.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0004.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0014.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0029.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0001.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0104.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0170.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0053.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0100.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0013.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0021.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0078.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0167.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0004.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0093.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0195.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0011.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0009.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0166.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0191.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0129.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0090.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0192.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0202.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0023.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0125.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0140.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0110.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0034.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0029.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0133.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0119.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0183.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0021.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0029.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0174.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0115.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0042.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0198.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0023.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0134.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0031.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0068.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0109.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0096.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0007.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0080.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0091.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0160.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0135.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0156.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0005.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0117.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0098.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0080.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0030.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0059.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0159.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0148.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0100.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0001.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0203.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0107.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0044.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0013.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0016.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0078.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0029.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0194.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0128.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0190.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0151.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0170.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0208.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0205.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0189.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0018.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0039.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0175.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0177.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0152.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0199.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0033.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0145.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0014.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0017.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0149.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0155.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0018.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0011.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0191.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0138.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0190.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0129.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0119.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0128.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0193.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0046.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0136.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0154.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0013.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0179.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0078.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0126.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0019.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0096.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0011.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0042.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0002.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0111.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0200.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0171.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0009.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0080.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0164.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0184.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0106.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0068.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0031.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0109.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0174.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0143.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0196.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0020.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0009.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0105.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0009.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0148.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0211.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0114.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0127.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0038.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0010.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0103.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0210.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0177.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0068.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0145.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0017.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0118.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0193.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0039.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0060.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0015.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0005.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0121.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0180.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0030.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0190.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0129.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0131.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0022.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0002.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0054.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0009.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0100.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0022.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0046.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0097.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0092.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0024.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0174.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0066.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0159.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0173.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0044.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0074.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0151.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0046.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0012.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0059.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0104.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0005.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0171.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0080.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0034.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0042.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0109.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0205.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0066.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0017.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0181.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0033.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0128.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0108.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0013.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0015.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0107.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0068.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0002.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0039.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0019.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0129.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0007.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0204.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0192.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0033.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0007.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0027.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0101.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0183.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0031.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0110.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0077.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0004.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0054.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0097.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0097.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0116.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0034.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0002.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0044.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0022.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0046.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0121.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0020.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0029.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0144.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0107.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0038.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0124.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0194.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0156.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0078.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0033.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0152.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0016.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0136.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0046.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0134.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0181.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0158.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0110.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0139.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0159.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0205.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0198.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0146.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0031.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0018.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0197.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0024.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0141.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0083.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0127.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0149.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0204.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0104.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0107.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0059.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0038.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0053.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0091.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0153.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0106.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0015.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0010.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0203.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0074.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0042.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0100.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0175.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0171.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0111.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0189.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0168.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0093.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0126.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0215.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0186.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0049.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0015.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0182.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0172.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0108.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0004.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0166.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0160.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0132.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0134.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0075.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0059.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0068.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0010.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0080.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0185.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0130.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0101.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0123.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0014.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0169.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0103.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0039.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0025.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0138.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0054.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0024.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0174.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0134.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0053.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0010.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0019.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0032.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0102.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0020.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0161.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0176.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0060.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0020.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0122.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0110.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0194.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0103.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0179.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0038.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0136.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0096.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0002.npy: shape (256, 256)
# ...
# Loaded /content/all_images_only/patient_29_29_slice_0118.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0150.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0078.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0133.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0021.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0171.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0158.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0074.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0003.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0074.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0101.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0116.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0060.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0094.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0229.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0130.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0023.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0044.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0130.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0031.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0195.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0047.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0112.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0022.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0172.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0179.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0023.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0037.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0120.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0051.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0087.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0232.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0034.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0039.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0030.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0104.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0085.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0211.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0125.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0012.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0130.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0160.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0006.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0048.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0201.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0098.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0092.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0060.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0125.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0224.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0096.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0012.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0149.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0040.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0091.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0205.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0099.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0069.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0030.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0108.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0005.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0155.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0082.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0184.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0088.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0206.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0007.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0090.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0114.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0053.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0019.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0194.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0045.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0012.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0058.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0102.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0042.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0113.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0003.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0076.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0186.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0065.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0081.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0079.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0225.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0204.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0106.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0197.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0012.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0154.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0093.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0013.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0066.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0056.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_10_10_slice_0098.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0127.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0120.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0062.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0131.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0021.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0010.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0000.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0054.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_14_14_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0089.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0070.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0179.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0095.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_8_8_slice_0055.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0008.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0138.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_22_22_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_16_16_slice_0026.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0103.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0063.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0035.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0071.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_26_26_slice_0015.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0157.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_5_5_slice_0041.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0064.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0057.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0145.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0084.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0101.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0072.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0086.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0182.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0061.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0052.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0028.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_2_2_slice_0050.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_18_18_slice_0017.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0122.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0092.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0067.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0187.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_19_19_slice_0023.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_25_25_slice_0090.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_24_24_slice_0043.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_6_6_slice_0073.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_28_28_slice_0002.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_23_23_slice_0158.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0115.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0105.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_30_30_slice_0118.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_27_27_slice_0141.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_21_21_slice_0109.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_1_1_slice_0036.npy: shape (256, 256)
# Loaded /content/all_images_only/patient_29_29_slice_0124.npy: shape (256, 256)
# Combined dataset: 2341 images with shape: (2341, 256, 256)
# Data type: float32, Min: 0.000, Max: 1.000
# Adding channel dimension for grayscale
# Final image shape: (2341, 1, 256, 256)
# Dataset size: 2341
# Number of batches per epoch: 585

# %%
# Model configuration optimized for 256x256 CT scans
model = UNet2DModel(
    sample_size=256,      # Your image size
    in_channels=1,        # Grayscale CT scans
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 512),  # Full capacity for better quality
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "AttnDownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "AttnUpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Print model information
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Model size: ~{total_params * 4 / 1024**2:.1f} MB")

# Scheduler optimized for medical images
noise_scheduler = DDPMScheduler(
    num_train_timesteps=1000,
    beta_schedule="scaled_linear",
    prediction_type="epsilon",
    clip_sample=False  # Don't clip for better quality
)

# Optimizer with medical image-specific settings
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=0.01,
    eps=1e-8,
    betas=(0.9, 0.999)
)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

# Mixed precision for memory efficiency
scaler = GradScaler()

# Training parameters
num_epochs = 10  # More epochs for better convergence
accumulation_steps = 8  # Effective batch size: 4 * 8 = 32
save_every = 2
log_every = 50

# Check GPU memory before training
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name()}")
    print(f"GPU Memory: {torch.cuda.memory_allocated()/1024**3:.2f}GB allocated")
    print(f"GPU Memory: {torch.cuda.memory_reserved()/1024**3:.2f}GB reserved")

# Training loop
global_step = 0
best_loss = float('inf')
train_losses = []

print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0

    progress_bar = tqdm(
        enumerate(train_dataloader),
        total=len(train_dataloader),
        desc=f"Epoch {epoch+1}/{num_epochs}"
    )

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)

        # Sample random timesteps
        timesteps = torch.randint(
            0,
            noise_scheduler.config.num_train_timesteps,
            (clean_images.shape[0],),
            device=device
        ).long()

        # Add noise to the clean images
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        # Forward pass with mixed precision
        with autocast():
            # Predict the noise residual
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]

            # Calculate loss (MSE between predicted and actual noise)
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        # Backward pass
        scaler.scale(loss).backward()

        # Update parameters after accumulation steps
        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            # Gradient clipping for stability
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        # Track metrics
        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        # Update progress bar
        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })

        global_step += 1

        # Log and clear memory periodically
        if batch_idx % log_every == 0:
            train_losses.append(batch_loss)
            clear_memory()

    # End of epoch processing
    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    # Save best model
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    # Save periodic checkpoints
    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    # GPU memory check
    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

# Final model save
torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

# Plot training loss
if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

# Test the model with sample generation
print("🖼️  Generating test sample...")
model.eval()
with torch.no_grad():
    # Generate a sample
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)

    # Denoising process
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample

        # Show progress every 100 steps
        if i % 100 == 0:
            clear_memory()

    # Convert to numpy and save
    sample = (sample + 1) / 2  # Convert from [-1, 1] to [0, 1]
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]  # Remove batch and channel dims

    # Save sample
    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")

# Instructions for resuming training
print("\n🔄 To resume training from a checkpoint:")
print("""
checkpoint = torch.load('ddmp_ct_best_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
start_epoch = checkpoint['epoch'] + 1
""")

clear_memory()
print("🏁 All done!")
# Out:
# Total parameters: 58,222,209
# Trainable parameters: 58,222,209
# Model size: ~222.1 MB
# GPU: Tesla T4
# GPU Memory: 0.22GB allocated
# GPU Memory: 0.23GB reserved
# Starting training...
# Effective batch size: 32
# /tmp/ipython-input-2130815112.py:42: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Epoch 1/10:   0%|          | 0/585 [00:00<?, ?it/s]
# /tmp/ipython-input-2130815112.py:91: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/10 completed.
# Average loss: 0.1382
# ✅ New best model saved! Loss: 0.1382
# GPU Memory: 0.68GB allocated, 7.82GB reserved
# Epoch 2/10:   0%|          | 0/585 [00:00<?, ?it/s]
# /tmp/ipython-input-2130815112.py:91: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /usr/local/lib/python3.12/dist-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_safe_repr.py:128: FutureWarning: Accessing config attribute `__iter__` directly via 'UNet2DModel' object attribute is deprecated. Please access '__iter__' over 'UNet2DModel's config object instead, e.g. 'unet.config.__iter__'.
#   if not hasattr(obj, "__iter__"):
# /usr/local/lib/python3.12/dist-packages/diffusers/configuration_utils.py:141: FutureWarning: Accessing config attribute `__iter__` directly via 'DDPMScheduler' object attribute is deprecated. Please access '__iter__' over 'DDPMScheduler's config object instead, e.g. 'scheduler.config.__iter__'.
#   deprecate("direct config name access", "1.0.0", deprecation_message, standard_warn=False)

# %%
#modified diffusion model lightweight

import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# --- Data Loading Classes (Your code, unchanged) ---
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True):
        print(f"Loading numpy files from folder: {folder_path}")
        npy_files = glob.glob(os.path.join(folder_path, "*.npy"))
        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found in {folder_path}")
        print(f"Found {len(npy_files)} .npy files")
        all_images = []
        for npy_file in tqdm(npy_files, desc="Loading .npy files"):
            images = np.load(npy_file)
            print(f"Loaded {npy_file}: shape {images.shape}")
            if len(images.shape) == 2:
                images = images[None, :, :]
            elif len(images.shape) == 3:
                if images.shape[-1] == 1 or images.shape[-1] == 3:
                    images = images[None, :, :, :]
            all_images.append(images)
        self.images = np.concatenate(all_images, axis=0)
        print(f"Combined dataset: {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")
        if self.images.max() > 1.0:
            print("Normalizing images from [0, 255] to [0, 1]")
            self.images = self.images.astype(np.float32) / 255.0
        else:
            self.images = self.images.astype(np.float32)
        if len(self.images.shape) == 3:
            print("Adding channel dimension for grayscale")
            self.images = self.images[:, None, :, :]
        elif len(self.images.shape) == 4:
            if self.images.shape[-1] == 1:
                print("Converting from (N, H, W, 1) to (N, 1, H, W)")
                self.images = np.transpose(self.images, (0, 3, 1, 2))
            elif self.images.shape[1] != 1 and self.images.shape[1] != 3:
                print("Converting from (N, H, W, C) to (N, C, H, W)")
                self.images = np.transpose(self.images, (0, 3, 1, 2))
        print(f"Final image shape: {self.images.shape}")
        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        if len(image.shape) == 2:
            image = image[None, :, :]
        elif len(image.shape) == 3 and image.shape[0] != 1:
            if image.shape[0] == 3:
                image = np.mean(image, axis=0, keepdims=True)
        image = torch.from_numpy(image).float()
        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])
        image = image * 2.0 - 1.0
        return image

# --- Dataset and DataLoader Setup ---
folder_path = 'path/to/your/numpy/folder'
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8, # Your mini-batch size
    shuffle=True,
    num_workers=4, # INCREASED from 2 for faster data loading
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)
print(f"Dataset size: {len(train_dataset)}")
print(f"Number of batches per epoch: {len(train_dataloader)}")

# --- Model Configuration ---
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(32, 64, 128, 256), # REDUCED for faster training
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "AttnDownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "AttnUpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Model size: ~{total_params * 4 / 1024**2:.1f} MB")

# --- Training Setup ---
noise_scheduler = DDPMScheduler(
    num_train_timesteps=1000,
    beta_schedule="scaled_linear",
    prediction_type="epsilon",
    clip_sample=False
)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=0.01,
    eps=1e-8,
    betas=(0.9, 0.999)
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()

# Training parameters
num_epochs = 10
accumulation_steps = 4 # Your effective batch size: 8 * 4 = 32
save_every = 2
log_every = 50

# --- Training Loop ---
global_step = 0
best_loss = float('inf')
train_losses = []
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")
    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)
        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps
        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1
        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1
        if batch_idx % log_every == 0:
            train_losses.append(batch_loss)
            clear_memory()

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()
    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

print("🖼️  Generating test sample...")
model.eval()
with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 100 == 0:
            clear_memory()
    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]
    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🔄 To resume training from a checkpoint:")
print("""
checkpoint = torch.load('ddpm_ct_best_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
start_epoch = checkpoint['epoch'] + 1
""")
clear_memory()
print("🏁 All done!")

# %%
#diffusion model optimized code

import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        """
        Args:
            folder_path: Path to folder containing .npy files (can be nested)
            augment: Whether to apply data augmentation
            target_shape: The desired shape for all images (C, H, W)
        """
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape

        # Find all .npy files recursively in the folder
        npy_files = glob.iglob(os.path.join(folder_path, "**", "*.npy"), recursive=True)
        npy_files = list(npy_files) # Convert generator to list to check count

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")

        # Load and process numpy arrays directly into memory
        all_images_list = [] # Use a list to collect images before concatenating
        skipped_files = []

        for npy_file in tqdm(npy_files, desc="Loading and processing .npy files"):
            try:
                images = np.load(npy_file)
                original_shape = images.shape
                # print(f"Loaded {npy_file}: shape {original_shape}") # Commented out to reduce verbose output

                # --- Shape Handling and Filtering ---
                # Ensure images have the right dimensions for grayscale (N, 1, H, W)
                if len(images.shape) == 2:  # Single image (H, W)
                    images = images[None, None, :, :]  # Add batch and channel dimension -> (1, 1, H, W)
                elif len(images.shape) == 3:  # Could be (N, H, W) or (H, W, C)
                    if images.shape[-1] == 1: # (H, W, 1)
                         images = images[None, :, :, :] # Add batch dim -> (1, H, W, 1)
                         images = np.transpose(images, (0, 3, 1, 2)) # -> (1, 1, H, W)
                    elif images.shape[-1] == 3: # (H, W, 3)
                         images = images[None, :, :, :] # Add batch dim -> (1, H, W, 3)
                         images = np.mean(images, axis=-1, keepdims=True) # -> (1, H, W, 1)
                         images = np.transpose(images, (0, 3, 1, 2)) # -> (1, 1, H, W)
                    elif images.shape[0] > 1: # (N, H, W)
                         images = images[:, None, :, :] # Add channel dimension -> (N, 1, H, W)
                    else:
                         print(f"Skipping {npy_file}: Unexpected 3D shape {original_shape}")
                         skipped_files.append(npy_file)
                         continue
                elif len(images.shape) == 4: # Assuming (N, H, W, C) or (N, C, H, W)
                    if images.shape[1] > 1: # Assuming (N, C, H, W) or (N, H, W, C)
                         if images.shape[1] == 3: # If RGB (N, 3, H, W), convert to grayscale
                             images = np.mean(images, axis=1, keepdims=True) # (N, 1, H, W)
                         elif images.shape[-1] == 3: # If RGB (N, H, W, 3), convert to grayscale
                              images = np.mean(images, axis=-1, keepdims=True) # (N, H, W, 1)
                              images = np.transpose(images, (0, 3, 1, 2)) # (N, 1, H, W)
                         elif images.shape[-1] == 1: # If (N, H, W, 1), convert to (N, 1, H, W)
                              images = np.transpose(images, (0, 3, 1, 2))
                         elif images.shape[1] == 1: # Already (N, 1, H, W)
                             pass
                         else:
                             print(f"Skipping {npy_file}: Unexpected 4D shape with more than 1 channel {images.shape}")
                             skipped_files.append(npy_file)
                             continue
                    elif images.shape[1] == 1: # Already (N, 1, H, W)
                        pass
                else:
                     print(f"Skipping {npy_file}: Unexpected shape {original_shape}")
                     skipped_files.append(npy_file)
                     continue # Skip files with unexpected dimensions

                # --- Resize/Pad to Target Shape if necessary ---
                # This part is crucial for preloading if image sizes vary
                # The original code assumed all images were already target size.
                # To handle varying sizes, we would need resizing/padding logic here.
                # For this subtask, assuming images are already the target size (256x256)
                # based on the previous cell's output showing (2341, 1, 256, 256).
                # If sizes varied, this would need significant modification.

                # Check if the processed image batch matches the target shape (C, H, W) for each image in the batch
                if len(images.shape) == 4 and images.shape[1:] == self.target_shape:
                    # Normalize images to [0, 1] if not already normalized
                    if images.max() > 1.0:
                        images = images.astype(np.float32) / 255.0
                    else:
                         images = images.astype(np.float32) # Ensure float32 even if already normalized

                    all_images_list.append(images) # Append the batch of images
                else:
                     print(f"Skipping {npy_file}: Final shape {images.shape} does not match target batch shape (N, {self.target_shape})")
                     skipped_files.append(npy_file)


            except Exception as e:
                print(f"Error loading or processing {npy_file}: {e}")
                skipped_files.append(npy_file)
                continue # Skip files that cause errors

        if len(all_images_list) == 0:
             raise ValueError(f"No valid images loaded from {folder_path}. {len(skipped_files)} files were skipped.")


        print(f"\nSuccessfully loaded and processed {len(all_images_list)} image batches.")
        print(f"Skipped {len(skipped_files)} files due to errors or incorrect shape.")

        # Concatenate all images into a single numpy array
        try:
            self.images = np.concatenate(all_images_list, axis=0)
        except ValueError as e:
             print(f"Error concatenating images: {e}")
             # This should ideally not happen now if filtering worked correctly
             shapes = [img.shape for img in all_images_list]
             print(f"Encountered images with inconsistent shapes during final concat: {shapes}")
             raise ValueError("Images still have inconsistent shapes and cannot be concatenated after filtering.") from e


        print(f"Combined dataset (preloaded): {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")

        # The images are already normalized to [0, 1] and are float32 from the loading loop
        # No need for the separate normalization/dtype check here unless debugging

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Access the preloaded image directly
        image = self.images[idx].copy()  # (1, H, W) - copy to avoid modifying the original array

        # Ensure image is (1, H, W) for grayscale before returning (should already be this from init)
        # This check should ideally not be needed if __init__ is correct, but keep for safety
        if len(image.shape) == 3 and image.shape[0] != 1:
            if image.shape[0] == 3:
                image = np.mean(image, axis=0, keepdims=True)
            else:
                 print(f"Warning: Image in getitem has unexpected channel count ({image.shape[0]}). Expected 1.")
                 # Handle unexpected shape - e.g., return a zero tensor or raise error
                 # For now, let's just print a warning and hope it's not frequent

        # Convert to tensor
        image = torch.from_numpy(image).float() # Should already be float32 from init, but .float() is safe

        # Apply augmentation
        if self.augment and np.random.random() > 0.5:
            # Random horizontal flip
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        # Normalize to [-1, 1] for diffusion training
        image = image * 2.0 - 1.0

        return image

# Alternative: Single file dataset (your original code) - Keep for reference, but not used in this subtask
class SingleNumpyDataset(Dataset):
    def __init__(self, numpy_file_path, augment=True):
        """
        For when you have a single .npy file containing all images
        Args:
            numpy_file_path: Path to single .npy file containing images
            augment: Whether to apply data augmentation
        """
        print(f"Loading numpy array from single file: {numpy_file_path}")

        # Load numpy array
        self.images = np.load(numpy_file_path)

        print(f"Loaded {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")

        # Normalize images to [0, 1] if not already normalized
        if self.images.max() > 1.0:
            print("Normalizing images from [0, 255] to [0, 1]")
            self.images = self.images.astype(np.float32) / 255.0
        else:
            self.images = self.images.astype(np.float32)

        # Ensure images have the right dimensions
        if len(self.images.shape) == 3:  # (N, H, W)
            print("Adding channel dimension")
            self.images = self.images[:, None, :, :]  # (N, 1, H, W)
        elif len(self.images.shape) == 4 and self.images.shape[-1] == 1:  # (N, H, W, 1)
            print("Converting from (N, H, W, 1) to (N, 1, H, W)")
            self.images = np.transpose(self.images, (0, 3, 1, 2))

        print(f"Final image shape: {self.images.shape}")

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()  # (1, H, W) or (H, W)

        # Ensure image is (1, H, W)
        if len(image.shape) == 2:
            image = image[None, :, :]

        # Convert to tensor
        image = torch.from_numpy(image).float()

        # Apply augmentation
        if self.augment and np.random.random() > 0.5:
            # Random horizontal flip
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        # Normalize to [-1, 1] for diffusion training
        image = image * 2.0 - 1.0

        return image


# Choose the appropriate dataset based on your setup
# Update this path to point to the directory containing the nested image folders
folder_path = "/content/drive/MyDrive/all_images_only" # UPDATED PATH

# OPTION 1: If you have multiple .npy files in a folder (your case)
train_dataset = MultipleNumpyDataset(folder_path, augment=True, target_shape=(1, 256, 256)) # Added target_shape

# OPTION 2: If you have a single .npy file containing all images
# single_file_path = 'path/to/your/single/file.npy'
# train_dataset = SingleNumpyDataset(single_file_path, augment=True)

# Rest of your training code remains the same...
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8, # Increased batch size
    shuffle=True,
    num_workers=4, # Increased num_workers
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

print(f"Dataset size: {len(train_dataset)}")
print(f"Number of batches per epoch: {len(train_dataloader)}")

# The rest of your training code continues unchanged...

# Model configuration optimized for 256x256 CT scans (slightly reduced for free tier)
model = UNet2DModel(
    sample_size=256,        # Your image size - Consider reducing this (e.g., to 128) for significant memory savings on free tier
    in_channels=1,          # Grayscale CT scans
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 256),  # Slightly reduced capacity
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "DownBlock2D", "DownBlock2D"), # Reduced attention blocks
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "UpBlock2D", "UpBlock2D"), # Reduced attention blocks
    attention_head_dim=8,
)
model.to(device)

# Print model information
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Model size: ~{total_params * 4 / 1024**2:.1f} MB")


# Scheduler optimized for medical images
noise_scheduler = DDPMScheduler(
    num_train_timesteps=1000,
    beta_schedule="scaled_linear",
    prediction_type="epsilon",
    clip_sample=False  # Don't clip for better quality
)

# Optimizer with medical image-specific settings
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4, # May need slight adjustment with reduced batch size/accumulation
    weight_decay=0.01,
    eps=1e-8,
    betas=(0.9, 0.999)
)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10) # Adjust T_max based on num_epochs

# Mixed precision for memory efficiency
scaler = GradScaler()

# Training parameters
num_epochs = 15  # Increased epochs to compensate for smaller batch size per step
accumulation_steps = 4  # Reduced accumulation steps (8 * 4 = 32 effective batch size)
save_every = 2
log_every = 20 # Increased log frequency for better monitoring

# Check GPU memory before training
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name()}")
    print(f"GPU Memory: {torch.cuda.memory_allocated()/1024**3:.2f}GB allocated")
    print(f"GPU Memory: {torch.cuda.memory_reserved()/1024**3:.2f}GB reserved")

# Training loop
global_step = 0
best_loss = float('inf')
train_losses = []

print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0

    progress_bar = tqdm(
        enumerate(train_dataloader),
        total=len(train_dataloader),
        desc=f"Epoch {epoch+1}/{num_epochs}"
    )

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)

        # Sample random timesteps
        timesteps = torch.randint(
            0,
            noise_scheduler.config.num_train_timesteps,
            (clean_images.shape[0],),
            device=device
        ).long()

        # Add noise to the clean images
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        # Forward pass with mixed precision
        with autocast():
            # Predict the noise residual
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]

            # Calculate loss (MSE between predicted and actual noise)
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        # Backward pass
        scaler.scale(loss).backward()

        # Update parameters after accumulation steps
        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            # Gradient clipping for stability
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

            # Clear memory after parameter update
            clear_memory()


        # Track metrics
        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        # Update progress bar
        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })

        global_step += 1

        # Log periodically
        if batch_idx % log_every == 0:
             train_losses.append(batch_loss)
             # clear_memory() # Removed this clear_memory as it's now after scaler.step

    # End of epoch processing
    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    # Save best model
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    # Save periodic checkpoints
    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss,
            'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    # GPU memory check
    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

# Final model save
torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

# Plot training loss
if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

# Test the model with sample generation
'''print("🖼️  Generating test sample...")
model.eval()
with torch.no_grad():
    # Generate a sample
    sample_shape = (1, 1, 256, 256) # Note: If you reduced training image size, change this too
    sample = torch.randn(sample_shape, device=device)

    # Denoising process
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample

        # Show progress every 100 steps
        if i % 100 == 0: # Increased clear_memory frequency during inference
            clear_memory()


    # Convert to numpy and save
    sample = (sample + 1) / 2  # Convert from [-1, 1] to [0, 1]
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]  # Remove batch and channel dims

    # Save sample
    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256") # Update if you reduce resolution
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")

# Instructions for resuming training
print("\n🔄 To resume training from a checkpoint:")
print("""
checkpoint = torch.load('ddmp_ct_best_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
start_epoch = checkpoint['epoch'] + 1
# You might also need to load the scaler state if using mixed precision
# scaler.load_state_dict(checkpoint['scaler_state_dict'])
""")


clear_memory()
print("🏁 All done!")'''
# Out:
# Using device: cuda
# Loading numpy files from folder: /content/drive/MyDrive/all_images_only
# Found 2341 .npy files
# Loading and processing .npy files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Successfully loaded and processed 2341 image batches.
# Skipped 0 files due to errors or incorrect shape.
# Combined dataset (preloaded): 2341 images with shape: (2341, 1, 256, 256)
# Data type: float32, Min: 0.000, Max: 1.000
# Dataset size: 2341
# Number of batches per epoch: 292
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Total parameters: 24,907,905
# Trainable parameters: 24,907,905
# Model size: ~95.0 MB
# GPU: Tesla T4
# GPU Memory: 0.09GB allocated
# GPU Memory: 0.10GB reserved
# Starting training...
# Effective batch size: 32
# /tmp/ipython-input-2866276400.py:310: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Epoch 1/15:   0%|          | 0/292 [00:00<?, ?it/s]
# /tmp/ipython-input-2866276400.py:359: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/15 completed.
# Average loss: 0.1184
# ✅ New best model saved! Loss: 0.1184
# GPU Memory: 0.31GB allocated, 0.43GB reserved
# Epoch 2/15:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 2/15 completed.
# Average loss: 0.0453
# ✅ New best model saved! Loss: 0.0453
# 📁 Checkpoint saved for epoch 2
# GPU Memory: 0.31GB allocated, 0.42GB reserved
# Epoch 3/15:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 3/15 completed.
# Average loss: 0.0424
# ✅ New best model saved! Loss: 0.0424
# GPU Memory: 0.31GB allocated, 0.43GB reserved
# Epoch 4/15:   0%|          | 0/292 [00:00<?, ?it/s]

# %%
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape
        npy_files = list(glob.iglob(os.path.join(folder_path, "**", "*.npy"), recursive=True))

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")
        all_images_list = []
        skipped_files = []

        for npy_file in tqdm(npy_files, desc="Loading and processing .npy files"):
            try:
                images = np.load(npy_file)
                original_shape = images.shape
                if len(images.shape) == 2:
                    images = images[None, None, :, :]
                elif len(images.shape) == 3:
                    if images.shape[-1] == 1:
                        images = images[None, :, :, :]
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[-1] == 3:
                        images = images[None, :, :, :]
                        images = np.mean(images, axis=-1, keepdims=True)
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[0] > 1:
                        images = images[:, None, :, :]
                    else:
                        print(f"Skipping {npy_file}: Unexpected 3D shape {original_shape}")
                        skipped_files.append(npy_file)
                        continue
                elif len(images.shape) == 4:
                    if images.shape[1] > 1:
                        if images.shape[1] == 3:
                            images = np.mean(images, axis=1, keepdims=True)
                        elif images.shape[-1] == 3:
                            images = np.mean(images, axis=-1, keepdims=True)
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[-1] == 1:
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[1] == 1:
                            pass
                        else:
                            print(f"Skipping {npy_file}: Unexpected 4D shape with more than 1 channel {images.shape}")
                            skipped_files.append(npy_file)
                            continue
                    elif images.shape[1] == 1:
                        pass
                else:
                    print(f"Skipping {npy_file}: Unexpected shape {original_shape}")
                    skipped_files.append(npy_file)
                    continue

                if len(images.shape) == 4 and images.shape[1:] == self.target_shape:
                    if images.max() > 1.0:
                        images = images.astype(np.float32) / 255.0
                    else:
                        images = images.astype(np.float32)
                    all_images_list.append(images)
                else:
                    print(f"Skipping {npy_file}: Final shape {images.shape} does not match target batch shape (N, {self.target_shape})")
                    skipped_files.append(npy_file)

            except Exception as e:
                print(f"Error loading or processing {npy_file}: {e}")
                skipped_files.append(npy_file)
                continue

        if len(all_images_list) == 0:
            raise ValueError(f"No valid images loaded from {folder_path}. {len(skipped_files)} files were skipped.")

        print(f"\nSuccessfully loaded and processed {len(all_images_list)} image batches.")
        print(f"Skipped {len(skipped_files)} files due to errors or incorrect shape.")

        try:
            self.images = np.concatenate(all_images_list, axis=0)
        except ValueError as e:
            print(f"Error concatenating images: {e}")
            shapes = [img.shape for img in all_images_list]
            print(f"Encountered images with inconsistent shapes during final concat: {shapes}")
            raise ValueError("Images still have inconsistent shapes and cannot be concatenated after filtering.") from e

        print(f"Combined dataset (preloaded): {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")
        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        image = torch.from_numpy(image).float()

        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        return image * 2.0 - 1.0

# --- Main Script ---
# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Dataset and DataLoader setup
folder_path = '/content/drive/MyDrive/dataset-1/all_images_only'
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

# Model configuration
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(32, 64, 128, 256), # REDUCED for faster training
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "AttnDownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "AttnUpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Scheduler, Optimizer, Scaler, and Checkpointing
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()
best_loss = float('inf')

# --- Checkpoint Resuming Section (Modified for your specific case) ---
checkpoint_path = "/content/drive/MyDrive/dataset-1/ddpm_ct_checkpoint_epoch_2.pt" # Your specified checkpoint file
print(f"Loading checkpoint from {checkpoint_path}...")
checkpoint = torch.load(checkpoint_path, map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
start_epoch = checkpoint['epoch'] + 1 # This will be 2 + 1 = 3
best_loss = checkpoint['loss']
print(f"Resuming training from epoch {start_epoch}")

# Training parameters (Modified)
num_epochs = start_epoch + 3 # Train for 3 more epochs, so num_epochs will be 6
accumulation_steps = 4
save_every = 2
log_every = 20
global_step = checkpoint['global_step'] if 'global_step' in checkpoint else 0

# --- Training Loop ---
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(start_epoch, num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            clear_memory()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1

        if batch_idx % log_every == 0:
            pass # Removed logging the loss per batch here

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss, 'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss, 'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

# --- Inference Section ---
print("🖼  Generating test sample...")
model.eval()
noise_scheduler.set_timesteps(num_inference_steps=50) # Use the DDPMScheduler for inference

with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)

    for i, t in enumerate(tqdm(noise_scheduler.timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 10 == 0: clear_memory()

    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]

    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🏁 All done!")

# %%
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape
        npy_files = list(glob.iglob(os.path.join(folder_path, "", "*.npy"), recursive=True))

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")
        all_images_list = []
        skipped_files = []

        for npy_file in tqdm(npy_files, desc="Loading and processing .npy files"):
            try:
                images = np.load(npy_file)
                original_shape = images.shape
                if len(images.shape) == 2:
                    images = images[None, None, :, :]
                elif len(images.shape) == 3:
                    if images.shape[-1] == 1:
                        images = images[None, :, :, :]
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[-1] == 3:
                        images = images[None, :, :, :]
                        images = np.mean(images, axis=-1, keepdims=True)
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[0] > 1:
                        images = images[:, None, :, :]
                    else:
                        print(f"Skipping {npy_file}: Unexpected 3D shape {original_shape}")
                        skipped_files.append(npy_file)
                        continue
                elif len(images.shape) == 4:
                    if images.shape[1] > 1:
                        if images.shape[1] == 3:
                            images = np.mean(images, axis=1, keepdims=True)
                        elif images.shape[-1] == 3:
                            images = np.mean(images, axis=-1, keepdims=True)
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[-1] == 1:
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[1] == 1:
                            pass
                        else:
                            print(f"Skipping {npy_file}: Unexpected 4D shape with more than 1 channel {images.shape}")
                            skipped_files.append(npy_file)
                            continue
                    elif images.shape[1] == 1:
                        pass
                else:
                    print(f"Skipping {npy_file}: Unexpected shape {original_shape}")
                    skipped_files.append(npy_file)
                    continue

                if len(images.shape) == 4 and images.shape[1:] == self.target_shape:
                    if images.max() > 1.0:
                        images = images.astype(np.float32) / 255.0
                    else:
                        images = images.astype(np.float32)
                    all_images_list.append(images)
                else:
                    print(f"Skipping {npy_file}: Final shape {images.shape} does not match target batch shape (N, {self.target_shape})")
                    skipped_files.append(npy_file)

            except Exception as e:
                print(f"Error loading or processing {npy_file}: {e}")
                skipped_files.append(npy_file)
                continue

        if len(all_images_list) == 0:
            raise ValueError(f"No valid images loaded from {folder_path}. {len(skipped_files)} files were skipped.")

        try:
            self.images = np.concatenate(all_images_list, axis=0)
        except ValueError as e:
            print(f"Error concatenating images: {e}")
            shapes = [img.shape for img in all_images_list]
            print(f"Encountered images with inconsistent shapes during final concat: {shapes}")
            raise ValueError("Images still have inconsistent shapes and cannot be concatenated after filtering.") from e

        print(f"Combined dataset (preloaded): {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")
        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        image = torch.from_numpy(image).float()

        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        return image * 2.0 - 1.0

# --- Main Script ---
# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Dataset and DataLoader setup
folder_path = '/content/drive/MyDrive/dataset-1/all_images_only'
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

# Model configuration
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 256),
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "DownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "UpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Scheduler, Optimizer, Scaler, and Checkpointing
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()
best_loss = float('inf')

# --- Checkpoint Resuming Section ---
checkpoint_path = "ddpm_ct_checkpoint_epoch_2.pt"
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    best_loss = checkpoint['loss']
    print(f"Resuming training from epoch {start_epoch}")
else:
    print("No checkpoint found. Starting training from scratch.")
    start_epoch = 0

# Training parameters
num_epochs = start_epoch + 3
accumulation_steps = 4
save_every = 2
log_every = 20
global_step = checkpoint['global_step'] if os.path.exists(checkpoint_path) and 'global_step' in checkpoint else 0

# --- Training Loop ---
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(start_epoch, num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            clear_memory()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1

        if batch_idx % log_every == 0:
            pass

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss, 'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss, 'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

# Plot training loss
if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

# Test the model with sample generation
print("🖼  Generating test sample...")
model.eval()
with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 100 == 0:
            clear_memory()

    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]

    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🏁 All done!")
# Out:
# Using device: cuda
# Using device: cuda
# Loading numpy files from folder: /content/drive/MyDrive/dataset-1/all_images_only
# Found 2341 .npy files
# Loading and processing .npy files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Combined dataset (preloaded): 2341 images with shape: (2341, 1, 256, 256)
# Data type: float32, Min: 0.000, Max: 1.000
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# No checkpoint found. Starting training from scratch.
# Starting training...
# Effective batch size: 32
# /tmp/ipython-input-4066274599.py:157: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Epoch 1/3:   0%|          | 0/292 [00:00<?, ?it/s]
# /tmp/ipython-input-4066274599.py:198: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/3 completed.
# Average loss: 0.1008
# ✅ New best model saved! Loss: 0.1008
# GPU Memory: 1.26GB allocated, 2.39GB reserved
# Epoch 2/3:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 2/3 completed.
# Average loss: 0.0292
# ✅ New best model saved! Loss: 0.0292
# 📁 Checkpoint saved for epoch 2
# GPU Memory: 1.26GB allocated, 2.12GB reserved
# Epoch 3/3:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 3/3 completed.
# Average loss: 0.0252
# ✅ New best model saved! Loss: 0.0252
# GPU Memory: 1.26GB allocated, 2.12GB reserved
# 🎉 Training completed!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4066274599.py in <cell line: 0>()
#     263
#     264 # Plot training loss
# --> 265 if train_losses:
#     266     plt.figure(figsize=(10, 5))
#     267     plt.plot(train_losses)
#
# NameError: name 'train_losses' is not defined

# %% [markdown]
# CNN TESTING

# %%
# --- PLEASE UPDATE THESE PATHS ---

# Path to your trained .keras model file
MODEL_PATH = '/content/drive/MyDrive/dataset-1/liver_unet.keras'

# Path to the parent folder containing your patient folders (e.g., Patient_13, etc.)
DATA_DIR = '/content/drive/MyDrive/dataset-1/Preprocessed_CNN_TEST'

# Directory where the prediction images will be saved
RESULTS_DIR = '/content/drive/MyDrive/dataset-1/Result CNN Test'

# %%
# --- Cell 2: The Main Prediction Script (Tests All NPZ Files with Patient ID Naming) ---
import os
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K

# --- CUSTOM FUNCTIONS (Needed to load the model) ---
def dice_coef(y_true, y_pred, smooth=1): return None
def dice_loss(y_true, y_pred): return None
def combined_loss(y_true, y_pred): return None

# --- MAIN WORKFLOW ---
def main(model_path, data_dir, results_dir):
    print("🚀 Starting U-Net Prediction on ALL NPZ Slices 🚀"); print("=" * 60)

    # 1. Load the U-Net Model
    print(f"Loading model from: {model_path}")
    try:
        model = keras.models.load_model(
            model_path,
            custom_objects={'dice_coef': dice_coef, 'dice_loss': dice_loss, 'combined_loss': combined_loss},
            safe_mode=False,
            compile=False
        )
        print("✅ Model loaded successfully!")
        target_size = model.input_shape[1:3]
        print(f"Model expects input size: {target_size}")
    except Exception as e:
        print(f"❌ Error loading model: {e}"); return

    # 2. Find all NPZ files
    npz_files = list(glob.glob(os.path.join(data_dir, '**', '*.npz'), recursive=True))
    if not npz_files:
        print(f"❌ Error: No .npz files found in {data_dir}."); return
    total_files = len(npz_files)
    print(f"Found {total_files} total .npz slice files to process.")

    os.makedirs(results_dir, exist_ok=True)

    # 3. Process every file
    for i, file_path in enumerate(npz_files):
        print(f"--- Processing file {i+1}/{total_files}: {os.path.basename(file_path)} ---")

        # Load the NPZ file
        try:
            with np.load(file_path) as data:
                if 'image' in data: ct_slice = data['image']
                elif 'data' in data: ct_slice = data['data']
                elif 'arr_0' in data: ct_slice = data['arr_0']
                else:
                    print(f"  - Warning: Could not find a valid data key. Skipping.")
                    continue

            if ct_slice.ndim != 2:
                print(f"  - Warning: Expected a 2D array but got shape {ct_slice.shape}. Skipping.")
                continue
        except Exception as e:
            print(f"  - Warning: Could not load file. Error: {e}. Skipping.")
            continue

        # 4. Preprocess the slice
        slice_resized = tf.image.resize(ct_slice[..., tf.newaxis], target_size)
        slice_normalized = slice_resized / 255.0
        batch_to_predict = tf.expand_dims(slice_normalized, axis=0)

        # 5. Get Prediction
        predicted_masks = model.predict(batch_to_predict, verbose=0)
        predicted_mask = predicted_masks[0]

        # 6. Create and Save the visualization for this slice
        plt.figure(figsize=(8, 4))

        # Get patient and slice identifiers for the title and filename
        slice_filename = os.path.splitext(os.path.basename(file_path))[0]
        patient_folder_name = os.path.basename(os.path.dirname(file_path))

        plt.subplot(1, 2, 1)
        plt.title(f"Input: {patient_folder_name} / {slice_filename}")
        plt.imshow(slice_normalized.numpy().squeeze(), cmap='gray')
        plt.axis('off')

        plt.subplot(1, 2, 2)
        plt.title("Predicted Mask")
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.axis('off')

        # *** MODIFIED NAMING CONVENTION IS HERE ***
        # Save the figure with a unique name: PatientFolder_SliceFilename_prediction.png
        output_filename = f"{patient_folder_name}_{slice_filename}_prediction.png"
        vis_path = os.path.join(results_dir, output_filename)
        plt.tight_layout()
        plt.savefig(vis_path, dpi=100)
        plt.close() # Close the figure to free up memory

    print(f"\n🖼️  All {total_files} prediction images have been saved to: {results_dir}")
    print("\n✅ Prediction completed successfully!")

# Run the main workflow
main(MODEL_PATH, DATA_DIR, RESULTS_DIR)
# Out:
# 🚀 Starting U-Net Prediction on ALL NPZ Slices 🚀
# ============================================================
# Loading model from: /content/drive/MyDrive/dataset-1/liver_unet.keras
# ✅ Model loaded successfully!
# Model expects input size: (256, 256)
# Found 3533 total .npz slice files to process.
# --- Processing file 1/3533: slice_0000.npz ---
# --- Processing file 2/3533: slice_0001.npz ---
# --- Processing file 3/3533: slice_0003.npz ---
# --- Processing file 4/3533: slice_0002.npz ---
# --- Processing file 5/3533: slice_0005.npz ---
# --- Processing file 6/3533: slice_0004.npz ---
# --- Processing file 7/3533: slice_0007.npz ---
# --- Processing file 8/3533: slice_0016.npz ---
# --- Processing file 9/3533: slice_0010.npz ---
# --- Processing file 10/3533: slice_0019.npz ---
# --- Processing file 11/3533: slice_0014.npz ---
# --- Processing file 12/3533: slice_0017.npz ---
# --- Processing file 13/3533: slice_0012.npz ---
# --- Processing file 14/3533: slice_0009.npz ---
# --- Processing file 15/3533: slice_0021.npz ---
# --- Processing file 16/3533: slice_0022.npz ---
# --- Processing file 17/3533: slice_0013.npz ---
# --- Processing file 18/3533: slice_0023.npz ---
# --- Processing file 19/3533: slice_0018.npz ---
# --- Processing file 20/3533: slice_0020.npz ---
# --- Processing file 21/3533: slice_0008.npz ---
# --- Processing file 22/3533: slice_0024.npz ---
# --- Processing file 23/3533: slice_0006.npz ---
# --- Processing file 24/3533: slice_0015.npz ---
# --- Processing file 25/3533: slice_0011.npz ---
# --- Processing file 26/3533: slice_0036.npz ---
# --- Processing file 27/3533: slice_0045.npz ---
# --- Processing file 28/3533: slice_0035.npz ---
# --- Processing file 29/3533: slice_0029.npz ---
# --- Processing file 30/3533: slice_0042.npz ---
# --- Processing file 31/3533: slice_0040.npz ---
# --- Processing file 32/3533: slice_0025.npz ---
# --- Processing file 33/3533: slice_0044.npz ---
# --- Processing file 34/3533: slice_0032.npz ---
# --- Processing file 35/3533: slice_0039.npz ---
# --- Processing file 36/3533: slice_0026.npz ---
# --- Processing file 37/3533: slice_0041.npz ---
# --- Processing file 38/3533: slice_0037.npz ---
# --- Processing file 39/3533: slice_0033.npz ---
# --- Processing file 40/3533: slice_0027.npz ---
# --- Processing file 41/3533: slice_0043.npz ---
# --- Processing file 42/3533: slice_0038.npz ---
# --- Processing file 43/3533: slice_0034.npz ---
# --- Processing file 44/3533: slice_0030.npz ---
# --- Processing file 45/3533: slice_0028.npz ---
# --- Processing file 46/3533: slice_0031.npz ---
# --- Processing file 47/3533: slice_0051.npz ---
# --- Processing file 48/3533: slice_0048.npz ---
# --- Processing file 49/3533: slice_0063.npz ---
# --- Processing file 50/3533: slice_0047.npz ---
# --- Processing file 51/3533: slice_0053.npz ---
# --- Processing file 52/3533: slice_0046.npz ---
# --- Processing file 53/3533: slice_0052.npz ---
# --- Processing file 54/3533: slice_0066.npz ---
# --- Processing file 55/3533: slice_0065.npz ---
# --- Processing file 56/3533: slice_0060.npz ---
# --- Processing file 57/3533: slice_0064.npz ---
# --- Processing file 58/3533: slice_0058.npz ---
# --- Processing file 59/3533: slice_0068.npz ---
# --- Processing file 60/3533: slice_0061.npz ---
# --- Processing file 61/3533: slice_0055.npz ---
# --- Processing file 62/3533: slice_0054.npz ---
# --- Processing file 63/3533: slice_0050.npz ---
# --- Processing file 64/3533: slice_0062.npz ---
# --- Processing file 65/3533: slice_0059.npz ---
# --- Processing file 66/3533: slice_0057.npz ---
# --- Processing file 67/3533: slice_0067.npz ---
# --- Processing file 68/3533: slice_0049.npz ---
# --- Processing file 69/3533: slice_0056.npz ---
# --- Processing file 70/3533: slice_0080.npz ---
# --- Processing file 71/3533: slice_0079.npz ---
# --- Processing file 72/3533: slice_0074.npz ---
# --- Processing file 73/3533: slice_0085.npz ---
# --- Processing file 74/3533: slice_0086.npz ---
# --- Processing file 75/3533: slice_0088.npz ---
# --- Processing file 76/3533: slice_0071.npz ---
# --- Processing file 77/3533: slice_0073.npz ---
# --- Processing file 78/3533: slice_0075.npz ---
# --- Processing file 79/3533: slice_0087.npz ---
# --- Processing file 80/3533: slice_0069.npz ---
# --- Processing file 81/3533: slice_0082.npz ---
# --- Processing file 82/3533: slice_0072.npz ---
# --- Processing file 83/3533: slice_0078.npz ---
# --- Processing file 84/3533: slice_0076.npz ---
# --- Processing file 85/3533: slice_0084.npz ---
# --- Processing file 86/3533: slice_0083.npz ---
# --- Processing file 87/3533: slice_0070.npz ---
# --- Processing file 88/3533: slice_0077.npz ---
# --- Processing file 89/3533: slice_0081.npz ---
# --- Processing file 90/3533: slice_0093.npz ---
# --- Processing file 91/3533: slice_0100.npz ---
# --- Processing file 92/3533: slice_0097.npz ---
# --- Processing file 93/3533: slice_0092.npz ---
# --- Processing file 94/3533: slice_0102.npz ---
# --- Processing file 95/3533: slice_0095.npz ---
# --- Processing file 96/3533: slice_0091.npz ---
# --- Processing file 97/3533: slice_0103.npz ---
# --- Processing file 98/3533: slice_0096.npz ---
# --- Processing file 99/3533: slice_0090.npz ---
# --- Processing file 100/3533: slice_0089.npz ---
# --- Processing file 101/3533: slice_0094.npz ---
# --- Processing file 102/3533: slice_0099.npz ---
# --- Processing file 103/3533: slice_0101.npz ---
# --- Processing file 104/3533: slice_0098.npz ---
# --- Processing file 105/3533: slice_0009.npz ---
# --- Processing file 106/3533: slice_0005.npz ---
# --- Processing file 107/3533: slice_0003.npz ---
# --- Processing file 108/3533: slice_0008.npz ---
# --- Processing file 109/3533: slice_0010.npz ---
# --- Processing file 110/3533: slice_0004.npz ---
# --- Processing file 111/3533: slice_0000.npz ---
# --- Processing file 112/3533: slice_0007.npz ---
# --- Processing file 113/3533: slice_0001.npz ---
# --- Processing file 114/3533: slice_0011.npz ---
# --- Processing file 115/3533: slice_0002.npz ---
# --- Processing file 116/3533: slice_0006.npz ---
# --- Processing file 117/3533: slice_0015.npz ---
# --- Processing file 118/3533: slice_0030.npz ---
# --- Processing file 119/3533: slice_0020.npz ---
# --- Processing file 120/3533: slice_0025.npz ---
# --- Processing file 121/3533: slice_0016.npz ---
# --- Processing file 122/3533: slice_0014.npz ---
# --- Processing file 123/3533: slice_0023.npz ---
# --- Processing file 124/3533: slice_0028.npz ---
# --- Processing file 125/3533: slice_0012.npz ---
# --- Processing file 126/3533: slice_0022.npz ---
# --- Processing file 127/3533: slice_0013.npz ---
# --- Processing file 128/3533: slice_0031.npz ---
# --- Processing file 129/3533: slice_0035.npz ---
# --- Processing file 130/3533: slice_0017.npz ---
# --- Processing file 131/3533: slice_0024.npz ---
# --- Processing file 132/3533: slice_0036.npz ---
# --- Processing file 133/3533: slice_0019.npz ---
# --- Processing file 134/3533: slice_0034.npz ---
# --- Processing file 135/3533: slice_0033.npz ---
# --- Processing file 136/3533: slice_0018.npz ---
# --- Processing file 137/3533: slice_0021.npz ---
# --- Processing file 138/3533: slice_0027.npz ---
# --- Processing file 139/3533: slice_0026.npz ---
# --- Processing file 140/3533: slice_0029.npz ---
# --- Processing file 141/3533: slice_0032.npz ---
# --- Processing file 142/3533: slice_0057.npz ---
# --- Processing file 143/3533: slice_0044.npz ---
# --- Processing file 144/3533: slice_0059.npz ---
# --- Processing file 145/3533: slice_0042.npz ---
# --- Processing file 146/3533: slice_0046.npz ---
# --- Processing file 147/3533: slice_0050.npz ---
# --- Processing file 148/3533: slice_0052.npz ---
# --- Processing file 149/3533: slice_0045.npz ---
# --- Processing file 150/3533: slice_0055.npz ---
# --- Processing file 151/3533: slice_0040.npz ---
# --- Processing file 152/3533: slice_0049.npz ---
# --- Processing file 153/3533: slice_0039.npz ---
# --- Processing file 154/3533: slice_0051.npz ---
# --- Processing file 155/3533: slice_0054.npz ---
# --- Processing file 156/3533: slice_0047.npz ---
# --- Processing file 157/3533: slice_0058.npz ---
# --- Processing file 158/3533: slice_0038.npz ---
# --- Processing file 159/3533: slice_0037.npz ---
# --- Processing file 160/3533: slice_0041.npz ---
# --- Processing file 161/3533: slice_0053.npz ---
# --- Processing file 162/3533: slice_0043.npz ---
# --- Processing file 163/3533: slice_0056.npz ---
# --- Processing file 164/3533: slice_0048.npz ---
# --- Processing file 165/3533: slice_0074.npz ---
# --- Processing file 166/3533: slice_0062.npz ---
# --- Processing file 167/3533: slice_0073.npz ---
# --- Processing file 168/3533: slice_0067.npz ---
# --- Processing file 169/3533: slice_0070.npz ---
# --- Processing file 170/3533: slice_0069.npz ---
# --- Processing file 171/3533: slice_0072.npz ---
# --- Processing file 172/3533: slice_0071.npz ---
# --- Processing file 173/3533: slice_0066.npz ---
# --- Processing file 174/3533: slice_0076.npz ---
# --- Processing file 175/3533: slice_0063.npz ---
# --- Processing file 176/3533: slice_0079.npz ---
# --- Processing file 177/3533: slice_0064.npz ---
# --- Processing file 178/3533: slice_0065.npz ---
# --- Processing file 179/3533: slice_0077.npz ---
# --- Processing file 180/3533: slice_0060.npz ---
# --- Processing file 181/3533: slice_0061.npz ---
# --- Processing file 182/3533: slice_0068.npz ---
# --- Processing file 183/3533: slice_0075.npz ---
# --- Processing file 184/3533: slice_0078.npz ---
# --- Processing file 185/3533: slice_0081.npz ---
# --- Processing file 186/3533: slice_0080.npz ---
# --- Processing file 187/3533: slice_0082.npz ---
# --- Processing file 188/3533: slice_0015.npz ---
# --- Processing file 189/3533: slice_0010.npz ---
# --- Processing file 190/3533: slice_0016.npz ---
# --- Processing file 191/3533: slice_0019.npz ---
# --- Processing file 192/3533: slice_0020.npz ---
# --- Processing file 193/3533: slice_0008.npz ---
# --- Processing file 194/3533: slice_0000.npz ---
# --- Processing file 195/3533: slice_0012.npz ---
# --- Processing file 196/3533: slice_0006.npz ---
# --- Processing file 197/3533: slice_0017.npz ---
# --- Processing file 198/3533: slice_0004.npz ---
# --- Processing file 199/3533: slice_0011.npz ---
# --- Processing file 200/3533: slice_0013.npz ---
# --- Processing file 201/3533: slice_0009.npz ---
# --- Processing file 202/3533: slice_0002.npz ---
# --- Processing file 203/3533: slice_0001.npz ---
# --- Processing file 204/3533: slice_0003.npz ---
# --- Processing file 205/3533: slice_0014.npz ---
# --- Processing file 206/3533: slice_0007.npz ---
# --- Processing file 207/3533: slice_0005.npz ---
# --- Processing file 208/3533: slice_0018.npz ---
# --- Processing file 209/3533: slice_0041.npz ---
# --- Processing file 210/3533: slice_0031.npz ---
# --- Processing file 211/3533: slice_0030.npz ---
# --- Processing file 212/3533: slice_0040.npz ---
# --- Processing file 213/3533: slice_0021.npz ---
# --- Processing file 214/3533: slice_0033.npz ---
# --- Processing file 215/3533: slice_0024.npz ---
# --- Processing file 216/3533: slice_0026.npz ---
# --- Processing file 217/3533: slice_0036.npz ---
# --- Processing file 218/3533: slice_0035.npz ---
# --- Processing file 219/3533: slice_0045.npz ---
# --- Processing file 220/3533: slice_0042.npz ---
# --- Processing file 221/3533: slice_0043.npz ---
# --- Processing file 222/3533: slice_0029.npz ---
# --- Processing file 223/3533: slice_0025.npz ---
# --- Processing file 224/3533: slice_0034.npz ---
# --- Processing file 225/3533: slice_0038.npz ---
# --- Processing file 226/3533: slice_0037.npz ---
# --- Processing file 227/3533: slice_0032.npz ---
# --- Processing file 228/3533: slice_0039.npz ---
# --- Processing file 229/3533: slice_0027.npz ---
# --- Processing file 230/3533: slice_0028.npz ---
# --- Processing file 231/3533: slice_0044.npz ---
# --- Processing file 232/3533: slice_0023.npz ---
# --- Processing file 233/3533: slice_0022.npz ---
# --- Processing file 234/3533: slice_0059.npz ---
# --- Processing file 235/3533: slice_0047.npz ---
# --- Processing file 236/3533: slice_0056.npz ---
# --- Processing file 237/3533: slice_0051.npz ---
# --- Processing file 238/3533: slice_0054.npz ---
# --- Processing file 239/3533: slice_0061.npz ---
# --- Processing file 240/3533: slice_0064.npz ---
# --- Processing file 241/3533: slice_0049.npz ---
# --- Processing file 242/3533: slice_0058.npz ---
# --- Processing file 243/3533: slice_0055.npz ---
# --- Processing file 244/3533: slice_0060.npz ---
# --- Processing file 245/3533: slice_0048.npz ---
# --- Processing file 246/3533: slice_0069.npz ---
# --- Processing file 247/3533: slice_0068.npz ---
# --- Processing file 248/3533: slice_0046.npz ---
# --- Processing file 249/3533: slice_0065.npz ---
# --- Processing file 250/3533: slice_0066.npz ---
# --- Processing file 251/3533: slice_0057.npz ---
# --- Processing file 252/3533: slice_0050.npz ---
# --- Processing file 253/3533: slice_0052.npz ---
# --- Processing file 254/3533: slice_0062.npz ---
# --- Processing file 255/3533: slice_0053.npz ---
# --- Processing file 256/3533: slice_0063.npz ---
# --- Processing file 257/3533: slice_0067.npz ---
# --- Processing file 258/3533: slice_0086.npz ---
# --- Processing file 259/3533: slice_0074.npz ---
# --- Processing file 260/3533: slice_0081.npz ---
# --- Processing file 261/3533: slice_0071.npz ---
# --- Processing file 262/3533: slice_0080.npz ---
# --- Processing file 263/3533: slice_0083.npz ---
# --- Processing file 264/3533: slice_0082.npz ---
# --- Processing file 265/3533: slice_0085.npz ---
# --- Processing file 266/3533: slice_0088.npz ---
# --- Processing file 267/3533: slice_0070.npz ---
# --- Processing file 268/3533: slice_0072.npz ---
# --- Processing file 269/3533: slice_0073.npz ---
# --- Processing file 270/3533: slice_0078.npz ---
# --- Processing file 271/3533: slice_0087.npz ---
# --- Processing file 272/3533: slice_0077.npz ---
# --- Processing file 273/3533: slice_0079.npz ---
# --- Processing file 274/3533: slice_0084.npz ---
# --- Processing file 275/3533: slice_0076.npz ---
# --- Processing file 276/3533: slice_0075.npz ---
# --- Processing file 277/3533: slice_0001.npz ---
# --- Processing file 278/3533: slice_0003.npz ---
# --- Processing file 279/3533: slice_0000.npz ---
# --- Processing file 280/3533: slice_0002.npz ---
# --- Processing file 281/3533: slice_0008.npz ---
# --- Processing file 282/3533: slice_0026.npz ---
# --- Processing file 283/3533: slice_0023.npz ---
# --- Processing file 284/3533: slice_0020.npz ---
# --- Processing file 285/3533: slice_0013.npz ---
# --- Processing file 286/3533: slice_0011.npz ---
# --- Processing file 287/3533: slice_0014.npz ---
# --- Processing file 288/3533: slice_0005.npz ---
# --- Processing file 289/3533: slice_0015.npz ---
# --- Processing file 290/3533: slice_0019.npz ---
# --- Processing file 291/3533: slice_0024.npz ---
# --- Processing file 292/3533: slice_0007.npz ---
# --- Processing file 293/3533: slice_0009.npz ---
# --- Processing file 294/3533: slice_0012.npz ---
# --- Processing file 295/3533: slice_0004.npz ---
# --- Processing file 296/3533: slice_0006.npz ---
# --- Processing file 297/3533: slice_0017.npz ---
# --- Processing file 298/3533: slice_0021.npz ---
# --- Processing file 299/3533: slice_0018.npz ---
# --- Processing file 300/3533: slice_0025.npz ---
# --- Processing file 301/3533: slice_0016.npz ---
# --- Processing file 302/3533: slice_0010.npz ---
# --- Processing file 303/3533: slice_0022.npz ---
# --- Processing file 304/3533: slice_0046.npz ---
# --- Processing file 305/3533: slice_0045.npz ---
# --- Processing file 306/3533: slice_0039.npz ---
# --- Processing file 307/3533: slice_0041.npz ---
# --- Processing file 308/3533: slice_0032.npz ---
# --- Processing file 309/3533: slice_0036.npz ---
# --- Processing file 310/3533: slice_0048.npz ---
# --- Processing file 311/3533: slice_0040.npz ---
# --- Processing file 312/3533: slice_0047.npz ---
# --- Processing file 313/3533: slice_0033.npz ---
# --- Processing file 314/3533: slice_0035.npz ---
# --- Processing file 315/3533: slice_0037.npz ---
# --- Processing file 316/3533: slice_0034.npz ---
# --- Processing file 317/3533: slice_0042.npz ---
# --- Processing file 318/3533: slice_0031.npz ---
# --- Processing file 319/3533: slice_0044.npz ---
# --- Processing file 320/3533: slice_0038.npz ---
# --- Processing file 321/3533: slice_0030.npz ---
# --- Processing file 322/3533: slice_0043.npz ---
# --- Processing file 323/3533: slice_0027.npz ---
# --- Processing file 324/3533: slice_0029.npz ---
# --- Processing file 325/3533: slice_0028.npz ---
# --- Processing file 326/3533: slice_0061.npz ---
# --- Processing file 327/3533: slice_0062.npz ---
# --- Processing file 328/3533: slice_0068.npz ---
# --- Processing file 329/3533: slice_0054.npz ---
# --- Processing file 330/3533: slice_0071.npz ---
# --- Processing file 331/3533: slice_0067.npz ---
# --- Processing file 332/3533: slice_0052.npz ---
# --- Processing file 333/3533: slice_0069.npz ---
# --- Processing file 334/3533: slice_0060.npz ---
# --- Processing file 335/3533: slice_0057.npz ---
# --- Processing file 336/3533: slice_0059.npz ---
# --- Processing file 337/3533: slice_0064.npz ---
# --- Processing file 338/3533: slice_0066.npz ---
# --- Processing file 339/3533: slice_0049.npz ---
# --- Processing file 340/3533: slice_0063.npz ---
# --- Processing file 341/3533: slice_0055.npz ---
# --- Processing file 342/3533: slice_0065.npz ---
# --- Processing file 343/3533: slice_0050.npz ---
# --- Processing file 344/3533: slice_0051.npz ---
# --- Processing file 345/3533: slice_0056.npz ---
# --- Processing file 346/3533: slice_0070.npz ---
# --- Processing file 347/3533: slice_0058.npz ---
# --- Processing file 348/3533: slice_0053.npz ---
# --- Processing file 349/3533: slice_0088.npz ---
# --- Processing file 350/3533: slice_0083.npz ---
# --- Processing file 351/3533: slice_0073.npz ---
# --- Processing file 352/3533: slice_0079.npz ---
# --- Processing file 353/3533: slice_0093.npz ---
# --- Processing file 354/3533: slice_0076.npz ---
# --- Processing file 355/3533: slice_0080.npz ---
# --- Processing file 356/3533: slice_0075.npz ---
# --- Processing file 357/3533: slice_0074.npz ---
# --- Processing file 358/3533: slice_0072.npz ---
# --- Processing file 359/3533: slice_0094.npz ---
# --- Processing file 360/3533: slice_0091.npz ---
# --- Processing file 361/3533: slice_0078.npz ---
# --- Processing file 362/3533: slice_0082.npz ---
# --- Processing file 363/3533: slice_0081.npz ---
# --- Processing file 364/3533: slice_0089.npz ---
# --- Processing file 365/3533: slice_0087.npz ---
# --- Processing file 366/3533: slice_0090.npz ---
# --- Processing file 367/3533: slice_0084.npz ---
# --- Processing file 368/3533: slice_0086.npz ---
# --- Processing file 369/3533: slice_0092.npz ---
# --- Processing file 370/3533: slice_0085.npz ---
# --- Processing file 371/3533: slice_0077.npz ---
# --- Processing file 372/3533: slice_0096.npz ---
# --- Processing file 373/3533: slice_0099.npz ---
# --- Processing file 374/3533: slice_0097.npz ---
# --- Processing file 375/3533: slice_0104.npz ---
# --- Processing file 376/3533: slice_0103.npz ---
# --- Processing file 377/3533: slice_0101.npz ---
# --- Processing file 378/3533: slice_0098.npz ---
# --- Processing file 379/3533: slice_0095.npz ---
# --- Processing file 380/3533: slice_0100.npz ---
# --- Processing file 381/3533: slice_0102.npz ---
# --- Processing file 382/3533: slice_0018.npz ---
# --- Processing file 383/3533: slice_0011.npz ---
# --- Processing file 384/3533: slice_0024.npz ---
# --- Processing file 385/3533: slice_0019.npz ---
# --- Processing file 386/3533: slice_0020.npz ---
# --- Processing file 387/3533: slice_0004.npz ---
# --- Processing file 388/3533: slice_0015.npz ---
# --- Processing file 389/3533: slice_0005.npz ---
# --- Processing file 390/3533: slice_0006.npz ---
# --- Processing file 391/3533: slice_0012.npz ---
# --- Processing file 392/3533: slice_0023.npz ---
# --- Processing file 393/3533: slice_0013.npz ---
# --- Processing file 394/3533: slice_0022.npz ---
# --- Processing file 395/3533: slice_0002.npz ---
# --- Processing file 396/3533: slice_0000.npz ---
# --- Processing file 397/3533: slice_0009.npz ---
# --- Processing file 398/3533: slice_0016.npz ---
# --- Processing file 399/3533: slice_0014.npz ---
# --- Processing file 400/3533: slice_0017.npz ---
# --- Processing file 401/3533: slice_0008.npz ---
# --- Processing file 402/3533: slice_0021.npz ---
# --- Processing file 403/3533: slice_0001.npz ---
# --- Processing file 404/3533: slice_0010.npz ---
# --- Processing file 405/3533: slice_0003.npz ---
# --- Processing file 406/3533: slice_0007.npz ---
# --- Processing file 407/3533: slice_0039.npz ---
# --- Processing file 408/3533: slice_0043.npz ---
# --- Processing file 409/3533: slice_0026.npz ---
# --- Processing file 410/3533: slice_0045.npz ---
# --- Processing file 411/3533: slice_0037.npz ---
# --- Processing file 412/3533: slice_0032.npz ---
# --- Processing file 413/3533: slice_0029.npz ---
# --- Processing file 414/3533: slice_0042.npz ---
# --- Processing file 415/3533: slice_0034.npz ---
# --- Processing file 416/3533: slice_0028.npz ---
# --- Processing file 417/3533: slice_0048.npz ---
# --- Processing file 418/3533: slice_0040.npz ---
# --- Processing file 419/3533: slice_0030.npz ---
# --- Processing file 420/3533: slice_0025.npz ---
# --- Processing file 421/3533: slice_0047.npz ---
# --- Processing file 422/3533: slice_0049.npz ---
# --- Processing file 423/3533: slice_0038.npz ---
# --- Processing file 424/3533: slice_0031.npz ---
# --- Processing file 425/3533: slice_0044.npz ---
# --- Processing file 426/3533: slice_0036.npz ---
# --- Processing file 427/3533: slice_0027.npz ---
# --- Processing file 428/3533: slice_0041.npz ---
# --- Processing file 429/3533: slice_0046.npz ---
# --- Processing file 430/3533: slice_0035.npz ---
# --- Processing file 431/3533: slice_0033.npz ---
# --- Processing file 432/3533: slice_0074.npz ---
# --- Processing file 433/3533: slice_0071.npz ---
# --- Processing file 434/3533: slice_0070.npz ---
# --- Processing file 435/3533: slice_0057.npz ---
# --- Processing file 436/3533: slice_0073.npz ---
# --- Processing file 437/3533: slice_0063.npz ---
# --- Processing file 438/3533: slice_0055.npz ---
# --- Processing file 439/3533: slice_0060.npz ---
# --- Processing file 440/3533: slice_0069.npz ---
# --- Processing file 441/3533: slice_0051.npz ---
# --- Processing file 442/3533: slice_0056.npz ---
# --- Processing file 443/3533: slice_0072.npz ---
# --- Processing file 444/3533: slice_0059.npz ---
# --- Processing file 445/3533: slice_0054.npz ---
# --- Processing file 446/3533: slice_0065.npz ---
# --- Processing file 447/3533: slice_0062.npz ---
# --- Processing file 448/3533: slice_0052.npz ---
# --- Processing file 449/3533: slice_0058.npz ---
# --- Processing file 450/3533: slice_0068.npz ---
# --- Processing file 451/3533: slice_0064.npz ---
# --- Processing file 452/3533: slice_0053.npz ---
# --- Processing file 453/3533: slice_0067.npz ---
# --- Processing file 454/3533: slice_0066.npz ---
# --- Processing file 455/3533: slice_0050.npz ---
# --- Processing file 456/3533: slice_0061.npz ---
# --- Processing file 457/3533: slice_0075.npz ---
# --- Processing file 458/3533: slice_0078.npz ---
# --- Processing file 459/3533: slice_0086.npz ---
# --- Processing file 460/3533: slice_0076.npz ---
# --- Processing file 461/3533: slice_0083.npz ---
# --- Processing file 462/3533: slice_0085.npz ---
# --- Processing file 463/3533: slice_0082.npz ---
# --- Processing file 464/3533: slice_0080.npz ---
# --- Processing file 465/3533: slice_0077.npz ---
# --- Processing file 466/3533: slice_0081.npz ---
# --- Processing file 467/3533: slice_0084.npz ---
# --- Processing file 468/3533: slice_0079.npz ---
# --- Processing file 469/3533: slice_0012.npz ---
# --- Processing file 470/3533: slice_0001.npz ---
# --- Processing file 471/3533: slice_0024.npz ---
# --- Processing file 472/3533: slice_0020.npz ---
# --- Processing file 473/3533: slice_0017.npz ---
# --- Processing file 474/3533: slice_0000.npz ---
# --- Processing file 475/3533: slice_0003.npz ---
# --- Processing file 476/3533: slice_0022.npz ---
# --- Processing file 477/3533: slice_0006.npz ---
# --- Processing file 478/3533: slice_0002.npz ---
# --- Processing file 479/3533: slice_0011.npz ---
# --- Processing file 480/3533: slice_0019.npz ---
# --- Processing file 481/3533: slice_0018.npz ---
# --- Processing file 482/3533: slice_0010.npz ---
# --- Processing file 483/3533: slice_0008.npz ---
# --- Processing file 484/3533: slice_0023.npz ---
# --- Processing file 485/3533: slice_0005.npz ---
# --- Processing file 486/3533: slice_0009.npz ---
# --- Processing file 487/3533: slice_0021.npz ---
# --- Processing file 488/3533: slice_0015.npz ---
# --- Processing file 489/3533: slice_0013.npz ---
# --- Processing file 490/3533: slice_0016.npz ---
# --- Processing file 491/3533: slice_0014.npz ---
# --- Processing file 492/3533: slice_0007.npz ---
# --- Processing file 493/3533: slice_0004.npz ---
# --- Processing file 494/3533: slice_0030.npz ---
# --- Processing file 495/3533: slice_0040.npz ---
# --- Processing file 496/3533: slice_0027.npz ---
# --- Processing file 497/3533: slice_0034.npz ---
# --- Processing file 498/3533: slice_0043.npz ---
# --- Processing file 499/3533: slice_0038.npz ---
# --- Processing file 500/3533: slice_0035.npz ---
# --- Processing file 501/3533: slice_0031.npz ---
# --- Processing file 502/3533: slice_0041.npz ---
# --- Processing file 503/3533: slice_0026.npz ---
# --- Processing file 504/3533: slice_0033.npz ---
# --- Processing file 505/3533: slice_0036.npz ---
# --- Processing file 506/3533: slice_0029.npz ---
# --- Processing file 507/3533: slice_0046.npz ---
# --- Processing file 508/3533: slice_0049.npz ---
# --- Processing file 509/3533: slice_0039.npz ---
# --- Processing file 510/3533: slice_0042.npz ---
# --- Processing file 511/3533: slice_0032.npz ---
# --- Processing file 512/3533: slice_0045.npz ---
# --- Processing file 513/3533: slice_0028.npz ---
# --- Processing file 514/3533: slice_0037.npz ---
# --- Processing file 515/3533: slice_0025.npz ---
# --- Processing file 516/3533: slice_0047.npz ---
# --- Processing file 517/3533: slice_0044.npz ---
# --- Processing file 518/3533: slice_0048.npz ---
# --- Processing file 519/3533: slice_0056.npz ---
# --- Processing file 520/3533: slice_0068.npz ---
# --- Processing file 521/3533: slice_0054.npz ---
# --- Processing file 522/3533: slice_0062.npz ---
# --- Processing file 523/3533: slice_0071.npz ---
# --- Processing file 524/3533: slice_0051.npz ---
# --- Processing file 525/3533: slice_0063.npz ---
# --- Processing file 526/3533: slice_0073.npz ---
# --- Processing file 527/3533: slice_0055.npz ---
# --- Processing file 528/3533: slice_0061.npz ---
# --- Processing file 529/3533: slice_0050.npz ---
# --- Processing file 530/3533: slice_0072.npz ---
# --- Processing file 531/3533: slice_0058.npz ---
# --- Processing file 532/3533: slice_0057.npz ---
# --- Processing file 533/3533: slice_0067.npz ---
# --- Processing file 534/3533: slice_0066.npz ---
# --- Processing file 535/3533: slice_0052.npz ---
# --- Processing file 536/3533: slice_0075.npz ---
# --- Processing file 537/3533: slice_0074.npz ---
# --- Processing file 538/3533: slice_0069.npz ---
# --- Processing file 539/3533: slice_0064.npz ---
# --- Processing file 540/3533: slice_0053.npz ---
# --- Processing file 541/3533: slice_0070.npz ---
# --- Processing file 542/3533: slice_0060.npz ---
# --- Processing file 543/3533: slice_0059.npz ---
# --- Processing file 544/3533: slice_0065.npz ---
# --- Processing file 545/3533: slice_0099.npz ---
# --- Processing file 546/3533: slice_0081.npz ---
# --- Processing file 547/3533: slice_0091.npz ---
# --- Processing file 548/3533: slice_0101.npz ---
# --- Processing file 549/3533: slice_0100.npz ---
# --- Processing file 550/3533: slice_0077.npz ---
# --- Processing file 551/3533: slice_0088.npz ---
# --- Processing file 552/3533: slice_0093.npz ---
# --- Processing file 553/3533: slice_0092.npz ---
# --- Processing file 554/3533: slice_0094.npz ---
# --- Processing file 555/3533: slice_0083.npz ---
# --- Processing file 556/3533: slice_0086.npz ---
# --- Processing file 557/3533: slice_0090.npz ---
# --- Processing file 558/3533: slice_0078.npz ---
# --- Processing file 559/3533: slice_0079.npz ---
# --- Processing file 560/3533: slice_0102.npz ---
# --- Processing file 561/3533: slice_0096.npz ---
# --- Processing file 562/3533: slice_0080.npz ---
# --- Processing file 563/3533: slice_0087.npz ---
# --- Processing file 564/3533: slice_0098.npz ---
# --- Processing file 565/3533: slice_0076.npz ---
# --- Processing file 566/3533: slice_0097.npz ---
# --- Processing file 567/3533: slice_0095.npz ---
# --- Processing file 568/3533: slice_0085.npz ---
# --- Processing file 569/3533: slice_0089.npz ---
# --- Processing file 570/3533: slice_0084.npz ---
# --- Processing file 571/3533: slice_0082.npz ---
# --- Processing file 572/3533: slice_0127.npz ---
# --- Processing file 573/3533: slice_0117.npz ---
# --- Processing file 574/3533: slice_0125.npz ---
# --- Processing file 575/3533: slice_0120.npz ---
# --- Processing file 576/3533: slice_0104.npz ---
# --- Processing file 577/3533: slice_0111.npz ---
# --- Processing file 578/3533: slice_0103.npz ---
# --- Processing file 579/3533: slice_0105.npz ---
# --- Processing file 580/3533: slice_0128.npz ---
# --- Processing file 581/3533: slice_0107.npz ---
# --- Processing file 582/3533: slice_0119.npz ---
# --- Processing file 583/3533: slice_0113.npz ---
# --- Processing file 584/3533: slice_0121.npz ---
# --- Processing file 585/3533: slice_0109.npz ---
# --- Processing file 586/3533: slice_0108.npz ---
# --- Processing file 587/3533: slice_0123.npz ---
# --- Processing file 588/3533: slice_0124.npz ---
# --- Processing file 589/3533: slice_0122.npz ---
# --- Processing file 590/3533: slice_0115.npz ---
# --- Processing file 591/3533: slice_0110.npz ---
# --- Processing file 592/3533: slice_0129.npz ---
# --- Processing file 593/3533: slice_0126.npz ---
# --- Processing file 594/3533: slice_0116.npz ---
# --- Processing file 595/3533: slice_0114.npz ---
# --- Processing file 596/3533: slice_0112.npz ---
# --- Processing file 597/3533: slice_0106.npz ---
# --- Processing file 598/3533: slice_0118.npz ---
# --- Processing file 599/3533: slice_0133.npz ---
# --- Processing file 600/3533: slice_0137.npz ---
# --- Processing file 601/3533: slice_0142.npz ---
# --- Processing file 602/3533: slice_0139.npz ---
# --- Processing file 603/3533: slice_0138.npz ---
# --- Processing file 604/3533: slice_0141.npz ---
# --- Processing file 605/3533: slice_0150.npz ---
# --- Processing file 606/3533: slice_0145.npz ---
# --- Processing file 607/3533: slice_0155.npz ---
# --- Processing file 608/3533: slice_0147.npz ---
# --- Processing file 609/3533: slice_0134.npz ---
# --- Processing file 610/3533: slice_0130.npz ---
# --- Processing file 611/3533: slice_0135.npz ---
# --- Processing file 612/3533: slice_0154.npz ---
# --- Processing file 613/3533: slice_0132.npz ---
# --- Processing file 614/3533: slice_0149.npz ---
# --- Processing file 615/3533: slice_0148.npz ---
# --- Processing file 616/3533: slice_0146.npz ---
# --- Processing file 617/3533: slice_0131.npz ---
# --- Processing file 618/3533: slice_0136.npz ---
# --- Processing file 619/3533: slice_0152.npz ---
# --- Processing file 620/3533: slice_0151.npz ---
# --- Processing file 621/3533: slice_0140.npz ---
# --- Processing file 622/3533: slice_0143.npz ---
# --- Processing file 623/3533: slice_0144.npz ---
# --- Processing file 624/3533: slice_0153.npz ---
# --- Processing file 625/3533: slice_0170.npz ---
# --- Processing file 626/3533: slice_0164.npz ---
# --- Processing file 627/3533: slice_0159.npz ---
# --- Processing file 628/3533: slice_0175.npz ---
# --- Processing file 629/3533: slice_0160.npz ---
# --- Processing file 630/3533: slice_0168.npz ---
# --- Processing file 631/3533: slice_0169.npz ---
# --- Processing file 632/3533: slice_0178.npz ---
# --- Processing file 633/3533: slice_0165.npz ---
# --- Processing file 634/3533: slice_0163.npz ---
# --- Processing file 635/3533: slice_0176.npz ---
# --- Processing file 636/3533: slice_0173.npz ---
# --- Processing file 637/3533: slice_0167.npz ---
# --- Processing file 638/3533: slice_0174.npz ---
# --- Processing file 639/3533: slice_0180.npz ---
# --- Processing file 640/3533: slice_0177.npz ---
# --- Processing file 641/3533: slice_0162.npz ---
# --- Processing file 642/3533: slice_0157.npz ---
# --- Processing file 643/3533: slice_0158.npz ---
# --- Processing file 644/3533: slice_0172.npz ---
# --- Processing file 645/3533: slice_0171.npz ---
# --- Processing file 646/3533: slice_0166.npz ---
# --- Processing file 647/3533: slice_0156.npz ---
# --- Processing file 648/3533: slice_0161.npz ---
# --- Processing file 649/3533: slice_0179.npz ---
# --- Processing file 650/3533: slice_0181.npz ---
# --- Processing file 651/3533: slice_0191.npz ---
# --- Processing file 652/3533: slice_0194.npz ---
# --- Processing file 653/3533: slice_0185.npz ---
# --- Processing file 654/3533: slice_0203.npz ---
# --- Processing file 655/3533: slice_0183.npz ---
# --- Processing file 656/3533: slice_0200.npz ---
# --- Processing file 657/3533: slice_0187.npz ---
# --- Processing file 658/3533: slice_0196.npz ---
# --- Processing file 659/3533: slice_0205.npz ---
# --- Processing file 660/3533: slice_0198.npz ---
# --- Processing file 661/3533: slice_0199.npz ---
# --- Processing file 662/3533: slice_0202.npz ---
# --- Processing file 663/3533: slice_0207.npz ---
# --- Processing file 664/3533: slice_0192.npz ---
# --- Processing file 665/3533: slice_0189.npz ---
# --- Processing file 666/3533: slice_0188.npz ---
# --- Processing file 667/3533: slice_0201.npz ---
# --- Processing file 668/3533: slice_0190.npz ---
# --- Processing file 669/3533: slice_0184.npz ---
# --- Processing file 670/3533: slice_0195.npz ---
# --- Processing file 671/3533: slice_0193.npz ---
# --- Processing file 672/3533: slice_0182.npz ---
# --- Processing file 673/3533: slice_0204.npz ---
# --- Processing file 674/3533: slice_0186.npz ---
# --- Processing file 675/3533: slice_0197.npz ---
# --- Processing file 676/3533: slice_0206.npz ---
# --- Processing file 677/3533: slice_0213.npz ---
# --- Processing file 678/3533: slice_0224.npz ---
# --- Processing file 679/3533: slice_0222.npz ---
# --- Processing file 680/3533: slice_0210.npz ---
# --- Processing file 681/3533: slice_0227.npz ---
# --- Processing file 682/3533: slice_0221.npz ---
# --- Processing file 683/3533: slice_0209.npz ---
# --- Processing file 684/3533: slice_0226.npz ---
# --- Processing file 685/3533: slice_0217.npz ---
# --- Processing file 686/3533: slice_0208.npz ---
# --- Processing file 687/3533: slice_0223.npz ---
# --- Processing file 688/3533: slice_0228.npz ---
# --- Processing file 689/3533: slice_0212.npz ---
# --- Processing file 690/3533: slice_0218.npz ---
# --- Processing file 691/3533: slice_0215.npz ---
# --- Processing file 692/3533: slice_0211.npz ---
# --- Processing file 693/3533: slice_0220.npz ---
# --- Processing file 694/3533: slice_0219.npz ---
# --- Processing file 695/3533: slice_0216.npz ---
# --- Processing file 696/3533: slice_0225.npz ---
# --- Processing file 697/3533: slice_0214.npz ---
# --- Processing file 698/3533: slice_0243.npz ---
# --- Processing file 699/3533: slice_0231.npz ---
# --- Processing file 700/3533: slice_0230.npz ---
# --- Processing file 701/3533: slice_0232.npz ---
# --- Processing file 702/3533: slice_0229.npz ---
# --- Processing file 703/3533: slice_0241.npz ---
# --- Processing file 704/3533: slice_0239.npz ---
# --- Processing file 705/3533: slice_0246.npz ---
# --- Processing file 706/3533: slice_0238.npz ---
# --- Processing file 707/3533: slice_0248.npz ---
# --- Processing file 708/3533: slice_0242.npz ---
# --- Processing file 709/3533: slice_0235.npz ---
# --- Processing file 710/3533: slice_0233.npz ---
# --- Processing file 711/3533: slice_0244.npz ---
# --- Processing file 712/3533: slice_0249.npz ---
# --- Processing file 713/3533: slice_0236.npz ---
# --- Processing file 714/3533: slice_0247.npz ---
# --- Processing file 715/3533: slice_0250.npz ---
# --- Processing file 716/3533: slice_0240.npz ---
# --- Processing file 717/3533: slice_0245.npz ---
# --- Processing file 718/3533: slice_0234.npz ---
# --- Processing file 719/3533: slice_0237.npz ---
# --- Processing file 720/3533: slice_0261.npz ---
# --- Processing file 721/3533: slice_0270.npz ---
# --- Processing file 722/3533: slice_0273.npz ---
# --- Processing file 723/3533: slice_0263.npz ---
# --- Processing file 724/3533: slice_0272.npz ---
# --- Processing file 725/3533: slice_0255.npz ---
# --- Processing file 726/3533: slice_0257.npz ---
# --- Processing file 727/3533: slice_0254.npz ---
# --- Processing file 728/3533: slice_0267.npz ---
# --- Processing file 729/3533: slice_0265.npz ---
# --- Processing file 730/3533: slice_0259.npz ---
# --- Processing file 731/3533: slice_0253.npz ---
# --- Processing file 732/3533: slice_0252.npz ---
# --- Processing file 733/3533: slice_0266.npz ---
# --- Processing file 734/3533: slice_0262.npz ---
# --- Processing file 735/3533: slice_0269.npz ---
# --- Processing file 736/3533: slice_0258.npz ---
# --- Processing file 737/3533: slice_0264.npz ---
# --- Processing file 738/3533: slice_0260.npz ---
# --- Processing file 739/3533: slice_0256.npz ---
# --- Processing file 740/3533: slice_0251.npz ---
# --- Processing file 741/3533: slice_0268.npz ---
# --- Processing file 742/3533: slice_0271.npz ---
# --- Processing file 743/3533: slice_0280.npz ---
# --- Processing file 744/3533: slice_0283.npz ---
# --- Processing file 745/3533: slice_0286.npz ---
# --- Processing file 746/3533: slice_0287.npz ---
# --- Processing file 747/3533: slice_0274.npz ---
# --- Processing file 748/3533: slice_0281.npz ---
# --- Processing file 749/3533: slice_0279.npz ---
# --- Processing file 750/3533: slice_0276.npz ---
# --- Processing file 751/3533: slice_0285.npz ---
# --- Processing file 752/3533: slice_0278.npz ---
# --- Processing file 753/3533: slice_0284.npz ---
# --- Processing file 754/3533: slice_0277.npz ---
# --- Processing file 755/3533: slice_0282.npz ---
# --- Processing file 756/3533: slice_0275.npz ---
# --- Processing file 757/3533: slice_0009.npz ---
# --- Processing file 758/3533: slice_0002.npz ---
# --- Processing file 759/3533: slice_0017.npz ---
# --- Processing file 760/3533: slice_0016.npz ---
# --- Processing file 761/3533: slice_0011.npz ---
# --- Processing file 762/3533: slice_0003.npz ---
# --- Processing file 763/3533: slice_0015.npz ---
# --- Processing file 764/3533: slice_0000.npz ---
# --- Processing file 765/3533: slice_0012.npz ---
# --- Processing file 766/3533: slice_0004.npz ---
# --- Processing file 767/3533: slice_0013.npz ---
# --- Processing file 768/3533: slice_0005.npz ---
# --- Processing file 769/3533: slice_0001.npz ---
# --- Processing file 770/3533: slice_0008.npz ---
# --- Processing file 771/3533: slice_0014.npz ---
# --- Processing file 772/3533: slice_0006.npz ---
# --- Processing file 773/3533: slice_0010.npz ---
# --- Processing file 774/3533: slice_0007.npz ---
# --- Processing file 775/3533: slice_0034.npz ---
# --- Processing file 776/3533: slice_0022.npz ---
# --- Processing file 777/3533: slice_0044.npz ---
# --- Processing file 778/3533: slice_0030.npz ---
# --- Processing file 779/3533: slice_0036.npz ---
# --- Processing file 780/3533: slice_0041.npz ---
# --- Processing file 781/3533: slice_0040.npz ---
# --- Processing file 782/3533: slice_0037.npz ---
# --- Processing file 783/3533: slice_0020.npz ---
# --- Processing file 784/3533: slice_0031.npz ---
# --- Processing file 785/3533: slice_0018.npz ---
# --- Processing file 786/3533: slice_0029.npz ---
# --- Processing file 787/3533: slice_0043.npz ---
# --- Processing file 788/3533: slice_0039.npz ---
# --- Processing file 789/3533: slice_0024.npz ---
# --- Processing file 790/3533: slice_0028.npz ---
# --- Processing file 791/3533: slice_0027.npz ---
# --- Processing file 792/3533: slice_0033.npz ---
# --- Processing file 793/3533: slice_0047.npz ---
# --- Processing file 794/3533: slice_0046.npz ---
# --- Processing file 795/3533: slice_0048.npz ---
# --- Processing file 796/3533: slice_0025.npz ---
# --- Processing file 797/3533: slice_0038.npz ---
# --- Processing file 798/3533: slice_0026.npz ---
# --- Processing file 799/3533: slice_0035.npz ---
# --- Processing file 800/3533: slice_0032.npz ---
# --- Processing file 801/3533: slice_0042.npz ---
# --- Processing file 802/3533: slice_0021.npz ---
# --- Processing file 803/3533: slice_0045.npz ---
# --- Processing file 804/3533: slice_0023.npz ---
# --- Processing file 805/3533: slice_0019.npz ---
# --- Processing file 806/3533: slice_0070.npz ---
# --- Processing file 807/3533: slice_0058.npz ---
# --- Processing file 808/3533: slice_0053.npz ---
# --- Processing file 809/3533: slice_0061.npz ---
# --- Processing file 810/3533: slice_0059.npz ---
# --- Processing file 811/3533: slice_0065.npz ---
# --- Processing file 812/3533: slice_0072.npz ---
# --- Processing file 813/3533: slice_0055.npz ---
# --- Processing file 814/3533: slice_0056.npz ---
# --- Processing file 815/3533: slice_0054.npz ---
# --- Processing file 816/3533: slice_0075.npz ---
# --- Processing file 817/3533: slice_0064.npz ---
# --- Processing file 818/3533: slice_0074.npz ---
# --- Processing file 819/3533: slice_0067.npz ---
# --- Processing file 820/3533: slice_0052.npz ---
# --- Processing file 821/3533: slice_0068.npz ---
# --- Processing file 822/3533: slice_0073.npz ---
# --- Processing file 823/3533: slice_0076.npz ---
# --- Processing file 824/3533: slice_0066.npz ---
# --- Processing file 825/3533: slice_0077.npz ---
# --- Processing file 826/3533: slice_0062.npz ---
# --- Processing file 827/3533: slice_0057.npz ---
# --- Processing file 828/3533: slice_0071.npz ---
# --- Processing file 829/3533: slice_0050.npz ---
# --- Processing file 830/3533: slice_0063.npz ---
# --- Processing file 831/3533: slice_0060.npz ---
# --- Processing file 832/3533: slice_0051.npz ---
# --- Processing file 833/3533: slice_0069.npz ---
# --- Processing file 834/3533: slice_0049.npz ---
# --- Processing file 835/3533: slice_0089.npz ---
# --- Processing file 836/3533: slice_0080.npz ---
# --- Processing file 837/3533: slice_0091.npz ---
# --- Processing file 838/3533: slice_0082.npz ---
# --- Processing file 839/3533: slice_0084.npz ---
# --- Processing file 840/3533: slice_0101.npz ---
# --- Processing file 841/3533: slice_0088.npz ---
# --- Processing file 842/3533: slice_0096.npz ---
# --- Processing file 843/3533: slice_0102.npz ---
# --- Processing file 844/3533: slice_0083.npz ---
# --- Processing file 845/3533: slice_0079.npz ---
# --- Processing file 846/3533: slice_0105.npz ---
# --- Processing file 847/3533: slice_0092.npz ---
# --- Processing file 848/3533: slice_0093.npz ---
# --- Processing file 849/3533: slice_0087.npz ---
# --- Processing file 850/3533: slice_0090.npz ---
# --- Processing file 851/3533: slice_0085.npz ---
# --- Processing file 852/3533: slice_0099.npz ---
# --- Processing file 853/3533: slice_0103.npz ---
# --- Processing file 854/3533: slice_0097.npz ---
# --- Processing file 855/3533: slice_0095.npz ---
# --- Processing file 856/3533: slice_0081.npz ---
# --- Processing file 857/3533: slice_0100.npz ---
# --- Processing file 858/3533: slice_0094.npz ---
# --- Processing file 859/3533: slice_0078.npz ---
# --- Processing file 860/3533: slice_0098.npz ---
# --- Processing file 861/3533: slice_0086.npz ---
# --- Processing file 862/3533: slice_0104.npz ---
# --- Processing file 863/3533: slice_0127.npz ---
# --- Processing file 864/3533: slice_0126.npz ---
# --- Processing file 865/3533: slice_0113.npz ---
# --- Processing file 866/3533: slice_0124.npz ---
# --- Processing file 867/3533: slice_0129.npz ---
# --- Processing file 868/3533: slice_0122.npz ---
# --- Processing file 869/3533: slice_0112.npz ---
# --- Processing file 870/3533: slice_0121.npz ---
# --- Processing file 871/3533: slice_0120.npz ---
# --- Processing file 872/3533: slice_0116.npz ---
# --- Processing file 873/3533: slice_0110.npz ---
# --- Processing file 874/3533: slice_0128.npz ---
# --- Processing file 875/3533: slice_0107.npz ---
# --- Processing file 876/3533: slice_0106.npz ---
# --- Processing file 877/3533: slice_0130.npz ---
# --- Processing file 878/3533: slice_0131.npz ---
# --- Processing file 879/3533: slice_0123.npz ---
# --- Processing file 880/3533: slice_0119.npz ---
# --- Processing file 881/3533: slice_0117.npz ---
# --- Processing file 882/3533: slice_0108.npz ---
# --- Processing file 883/3533: slice_0114.npz ---
# --- Processing file 884/3533: slice_0109.npz ---
# --- Processing file 885/3533: slice_0111.npz ---
# --- Processing file 886/3533: slice_0133.npz ---
# --- Processing file 887/3533: slice_0118.npz ---
# --- Processing file 888/3533: slice_0132.npz ---
# --- Processing file 889/3533: slice_0125.npz ---
# --- Processing file 890/3533: slice_0115.npz ---
# --- Processing file 891/3533: slice_0154.npz ---
# --- Processing file 892/3533: slice_0156.npz ---
# --- Processing file 893/3533: slice_0144.npz ---
# --- Processing file 894/3533: slice_0146.npz ---
# --- Processing file 895/3533: slice_0141.npz ---
# --- Processing file 896/3533: slice_0136.npz ---
# --- Processing file 897/3533: slice_0145.npz ---
# --- Processing file 898/3533: slice_0142.npz ---
# --- Processing file 899/3533: slice_0152.npz ---
# --- Processing file 900/3533: slice_0149.npz ---
# --- Processing file 901/3533: slice_0134.npz ---
# --- Processing file 902/3533: slice_0162.npz ---
# --- Processing file 903/3533: slice_0137.npz ---
# --- Processing file 904/3533: slice_0158.npz ---
# --- Processing file 905/3533: slice_0160.npz ---
# --- Processing file 906/3533: slice_0148.npz ---
# --- Processing file 907/3533: slice_0138.npz ---
# --- Processing file 908/3533: slice_0151.npz ---
# --- Processing file 909/3533: slice_0155.npz ---
# --- Processing file 910/3533: slice_0159.npz ---
# --- Processing file 911/3533: slice_0139.npz ---
# --- Processing file 912/3533: slice_0150.npz ---
# --- Processing file 913/3533: slice_0140.npz ---
# --- Processing file 914/3533: slice_0163.npz ---
# --- Processing file 915/3533: slice_0157.npz ---
# --- Processing file 916/3533: slice_0147.npz ---
# --- Processing file 917/3533: slice_0135.npz ---
# --- Processing file 918/3533: slice_0153.npz ---
# --- Processing file 919/3533: slice_0161.npz ---
# --- Processing file 920/3533: slice_0143.npz ---
# --- Processing file 921/3533: slice_0179.npz ---
# --- Processing file 922/3533: slice_0164.npz ---
# --- Processing file 923/3533: slice_0176.npz ---
# --- Processing file 924/3533: slice_0178.npz ---
# --- Processing file 925/3533: slice_0187.npz ---
# --- Processing file 926/3533: slice_0169.npz ---
# --- Processing file 927/3533: slice_0188.npz ---
# --- Processing file 928/3533: slice_0186.npz ---
# --- Processing file 929/3533: slice_0190.npz ---
# --- Processing file 930/3533: slice_0175.npz ---
# --- Processing file 931/3533: slice_0193.npz ---
# --- Processing file 932/3533: slice_0177.npz ---
# --- Processing file 933/3533: slice_0182.npz ---
# --- Processing file 934/3533: slice_0173.npz ---
# --- Processing file 935/3533: slice_0171.npz ---
# --- Processing file 936/3533: slice_0167.npz ---
# --- Processing file 937/3533: slice_0189.npz ---
# --- Processing file 938/3533: slice_0185.npz ---
# --- Processing file 939/3533: slice_0184.npz ---
# --- Processing file 940/3533: slice_0168.npz ---
# --- Processing file 941/3533: slice_0183.npz ---
# --- Processing file 942/3533: slice_0170.npz ---
# --- Processing file 943/3533: slice_0174.npz ---
# --- Processing file 944/3533: slice_0180.npz ---
# --- Processing file 945/3533: slice_0165.npz ---
# --- Processing file 946/3533: slice_0191.npz ---
# --- Processing file 947/3533: slice_0172.npz ---
# --- Processing file 948/3533: slice_0181.npz ---
# --- Processing file 949/3533: slice_0192.npz ---
# --- Processing file 950/3533: slice_0166.npz ---
# --- Processing file 951/3533: slice_0214.npz ---
# --- Processing file 952/3533: slice_0209.npz ---
# --- Processing file 953/3533: slice_0205.npz ---
# --- Processing file 954/3533: slice_0215.npz ---
# --- Processing file 955/3533: slice_0222.npz ---
# --- Processing file 956/3533: slice_0201.npz ---
# --- Processing file 957/3533: slice_0212.npz ---
# --- Processing file 958/3533: slice_0208.npz ---
# --- Processing file 959/3533: slice_0217.npz ---
# --- Processing file 960/3533: slice_0211.npz ---
# --- Processing file 961/3533: slice_0199.npz ---
# --- Processing file 962/3533: slice_0221.npz ---
# --- Processing file 963/3533: slice_0197.npz ---
# --- Processing file 964/3533: slice_0206.npz ---
# --- Processing file 965/3533: slice_0204.npz ---
# --- Processing file 966/3533: slice_0223.npz ---
# --- Processing file 967/3533: slice_0207.npz ---
# --- Processing file 968/3533: slice_0218.npz ---
# --- Processing file 969/3533: slice_0198.npz ---
# --- Processing file 970/3533: slice_0202.npz ---
# --- Processing file 971/3533: slice_0203.npz ---
# --- Processing file 972/3533: slice_0216.npz ---
# --- Processing file 973/3533: slice_0213.npz ---
# --- Processing file 974/3533: slice_0219.npz ---
# --- Processing file 975/3533: slice_0196.npz ---
# ...
# --- Processing file 3217/3533: slice_0137.npz ---
# --- Processing file 3218/3533: slice_0148.npz ---
# --- Processing file 3219/3533: slice_0173.npz ---
# --- Processing file 3220/3533: slice_0164.npz ---
# --- Processing file 3221/3533: slice_0167.npz ---
# --- Processing file 3222/3533: slice_0174.npz ---
# --- Processing file 3223/3533: slice_0179.npz ---
# --- Processing file 3224/3533: slice_0184.npz ---
# --- Processing file 3225/3533: slice_0181.npz ---
# --- Processing file 3226/3533: slice_0166.npz ---
# --- Processing file 3227/3533: slice_0168.npz ---
# --- Processing file 3228/3533: slice_0172.npz ---
# --- Processing file 3229/3533: slice_0170.npz ---
# --- Processing file 3230/3533: slice_0177.npz ---
# --- Processing file 3231/3533: slice_0185.npz ---
# --- Processing file 3232/3533: slice_0171.npz ---
# --- Processing file 3233/3533: slice_0178.npz ---
# --- Processing file 3234/3533: slice_0180.npz ---
# --- Processing file 3235/3533: slice_0175.npz ---
# --- Processing file 3236/3533: slice_0186.npz ---
# --- Processing file 3237/3533: slice_0162.npz ---
# --- Processing file 3238/3533: slice_0183.npz ---
# --- Processing file 3239/3533: slice_0163.npz ---
# --- Processing file 3240/3533: slice_0165.npz ---
# --- Processing file 3241/3533: slice_0169.npz ---
# --- Processing file 3242/3533: slice_0182.npz ---
# --- Processing file 3243/3533: slice_0176.npz ---
# --- Processing file 3244/3533: slice_0207.npz ---
# --- Processing file 3245/3533: slice_0203.npz ---
# --- Processing file 3246/3533: slice_0189.npz ---
# --- Processing file 3247/3533: slice_0191.npz ---
# --- Processing file 3248/3533: slice_0202.npz ---
# --- Processing file 3249/3533: slice_0208.npz ---
# --- Processing file 3250/3533: slice_0200.npz ---
# --- Processing file 3251/3533: slice_0199.npz ---
# --- Processing file 3252/3533: slice_0205.npz ---
# --- Processing file 3253/3533: slice_0194.npz ---
# --- Processing file 3254/3533: slice_0206.npz ---
# --- Processing file 3255/3533: slice_0195.npz ---
# --- Processing file 3256/3533: slice_0201.npz ---
# --- Processing file 3257/3533: slice_0193.npz ---
# --- Processing file 3258/3533: slice_0209.npz ---
# --- Processing file 3259/3533: slice_0198.npz ---
# --- Processing file 3260/3533: slice_0187.npz ---
# --- Processing file 3261/3533: slice_0190.npz ---
# --- Processing file 3262/3533: slice_0196.npz ---
# --- Processing file 3263/3533: slice_0188.npz ---
# --- Processing file 3264/3533: slice_0192.npz ---
# --- Processing file 3265/3533: slice_0204.npz ---
# --- Processing file 3266/3533: slice_0210.npz ---
# --- Processing file 3267/3533: slice_0197.npz ---
# --- Processing file 3268/3533: slice_0224.npz ---
# --- Processing file 3269/3533: slice_0232.npz ---
# --- Processing file 3270/3533: slice_0211.npz ---
# --- Processing file 3271/3533: slice_0213.npz ---
# --- Processing file 3272/3533: slice_0221.npz ---
# --- Processing file 3273/3533: slice_0223.npz ---
# --- Processing file 3274/3533: slice_0231.npz ---
# --- Processing file 3275/3533: slice_0226.npz ---
# --- Processing file 3276/3533: slice_0228.npz ---
# --- Processing file 3277/3533: slice_0212.npz ---
# --- Processing file 3278/3533: slice_0220.npz ---
# --- Processing file 3279/3533: slice_0218.npz ---
# --- Processing file 3280/3533: slice_0219.npz ---
# --- Processing file 3281/3533: slice_0214.npz ---
# --- Processing file 3282/3533: slice_0217.npz ---
# --- Processing file 3283/3533: slice_0227.npz ---
# --- Processing file 3284/3533: slice_0222.npz ---
# --- Processing file 3285/3533: slice_0225.npz ---
# --- Processing file 3286/3533: slice_0229.npz ---
# --- Processing file 3287/3533: slice_0230.npz ---
# --- Processing file 3288/3533: slice_0233.npz ---
# --- Processing file 3289/3533: slice_0215.npz ---
# --- Processing file 3290/3533: slice_0216.npz ---
# --- Processing file 3291/3533: slice_0235.npz ---
# --- Processing file 3292/3533: slice_0255.npz ---
# --- Processing file 3293/3533: slice_0237.npz ---
# --- Processing file 3294/3533: slice_0250.npz ---
# --- Processing file 3295/3533: slice_0254.npz ---
# --- Processing file 3296/3533: slice_0246.npz ---
# --- Processing file 3297/3533: slice_0242.npz ---
# --- Processing file 3298/3533: slice_0251.npz ---
# --- Processing file 3299/3533: slice_0245.npz ---
# --- Processing file 3300/3533: slice_0256.npz ---
# --- Processing file 3301/3533: slice_0241.npz ---
# --- Processing file 3302/3533: slice_0249.npz ---
# --- Processing file 3303/3533: slice_0253.npz ---
# --- Processing file 3304/3533: slice_0236.npz ---
# --- Processing file 3305/3533: slice_0252.npz ---
# --- Processing file 3306/3533: slice_0238.npz ---
# --- Processing file 3307/3533: slice_0248.npz ---
# --- Processing file 3308/3533: slice_0240.npz ---
# --- Processing file 3309/3533: slice_0247.npz ---
# --- Processing file 3310/3533: slice_0234.npz ---
# --- Processing file 3311/3533: slice_0244.npz ---
# --- Processing file 3312/3533: slice_0239.npz ---
# --- Processing file 3313/3533: slice_0243.npz ---
# --- Processing file 3314/3533: slice_0267.npz ---
# --- Processing file 3315/3533: slice_0271.npz ---
# --- Processing file 3316/3533: slice_0264.npz ---
# --- Processing file 3317/3533: slice_0268.npz ---
# --- Processing file 3318/3533: slice_0266.npz ---
# --- Processing file 3319/3533: slice_0270.npz ---
# --- Processing file 3320/3533: slice_0262.npz ---
# --- Processing file 3321/3533: slice_0257.npz ---
# --- Processing file 3322/3533: slice_0260.npz ---
# --- Processing file 3323/3533: slice_0269.npz ---
# --- Processing file 3324/3533: slice_0265.npz ---
# --- Processing file 3325/3533: slice_0261.npz ---
# --- Processing file 3326/3533: slice_0258.npz ---
# --- Processing file 3327/3533: slice_0259.npz ---
# --- Processing file 3328/3533: slice_0263.npz ---
# --- Processing file 3329/3533: slice_0022.npz ---
# --- Processing file 3330/3533: slice_0021.npz ---
# --- Processing file 3331/3533: slice_0000.npz ---
# --- Processing file 3332/3533: slice_0002.npz ---
# --- Processing file 3333/3533: slice_0005.npz ---
# --- Processing file 3334/3533: slice_0017.npz ---
# --- Processing file 3335/3533: slice_0014.npz ---
# --- Processing file 3336/3533: slice_0019.npz ---
# --- Processing file 3337/3533: slice_0010.npz ---
# --- Processing file 3338/3533: slice_0018.npz ---
# --- Processing file 3339/3533: slice_0013.npz ---
# --- Processing file 3340/3533: slice_0011.npz ---
# --- Processing file 3341/3533: slice_0009.npz ---
# --- Processing file 3342/3533: slice_0007.npz ---
# --- Processing file 3343/3533: slice_0015.npz ---
# --- Processing file 3344/3533: slice_0008.npz ---
# --- Processing file 3345/3533: slice_0004.npz ---
# --- Processing file 3346/3533: slice_0006.npz ---
# --- Processing file 3347/3533: slice_0016.npz ---
# --- Processing file 3348/3533: slice_0001.npz ---
# --- Processing file 3349/3533: slice_0012.npz ---
# --- Processing file 3350/3533: slice_0020.npz ---
# --- Processing file 3351/3533: slice_0003.npz ---
# --- Processing file 3352/3533: slice_0037.npz ---
# --- Processing file 3353/3533: slice_0023.npz ---
# --- Processing file 3354/3533: slice_0042.npz ---
# --- Processing file 3355/3533: slice_0033.npz ---
# --- Processing file 3356/3533: slice_0025.npz ---
# --- Processing file 3357/3533: slice_0024.npz ---
# --- Processing file 3358/3533: slice_0030.npz ---
# --- Processing file 3359/3533: slice_0035.npz ---
# --- Processing file 3360/3533: slice_0041.npz ---
# --- Processing file 3361/3533: slice_0034.npz ---
# --- Processing file 3362/3533: slice_0040.npz ---
# --- Processing file 3363/3533: slice_0036.npz ---
# --- Processing file 3364/3533: slice_0031.npz ---
# --- Processing file 3365/3533: slice_0039.npz ---
# --- Processing file 3366/3533: slice_0027.npz ---
# --- Processing file 3367/3533: slice_0026.npz ---
# --- Processing file 3368/3533: slice_0043.npz ---
# --- Processing file 3369/3533: slice_0032.npz ---
# --- Processing file 3370/3533: slice_0028.npz ---
# --- Processing file 3371/3533: slice_0029.npz ---
# --- Processing file 3372/3533: slice_0038.npz ---
# --- Processing file 3373/3533: slice_0061.npz ---
# --- Processing file 3374/3533: slice_0044.npz ---
# --- Processing file 3375/3533: slice_0050.npz ---
# --- Processing file 3376/3533: slice_0053.npz ---
# --- Processing file 3377/3533: slice_0057.npz ---
# --- Processing file 3378/3533: slice_0062.npz ---
# --- Processing file 3379/3533: slice_0058.npz ---
# --- Processing file 3380/3533: slice_0056.npz ---
# --- Processing file 3381/3533: slice_0046.npz ---
# --- Processing file 3382/3533: slice_0048.npz ---
# --- Processing file 3383/3533: slice_0055.npz ---
# --- Processing file 3384/3533: slice_0051.npz ---
# --- Processing file 3385/3533: slice_0045.npz ---
# --- Processing file 3386/3533: slice_0060.npz ---
# --- Processing file 3387/3533: slice_0054.npz ---
# --- Processing file 3388/3533: slice_0047.npz ---
# --- Processing file 3389/3533: slice_0052.npz ---
# --- Processing file 3390/3533: slice_0049.npz ---
# --- Processing file 3391/3533: slice_0059.npz ---
# --- Processing file 3392/3533: slice_0070.npz ---
# --- Processing file 3393/3533: slice_0069.npz ---
# --- Processing file 3394/3533: slice_0067.npz ---
# --- Processing file 3395/3533: slice_0077.npz ---
# --- Processing file 3396/3533: slice_0063.npz ---
# --- Processing file 3397/3533: slice_0068.npz ---
# --- Processing file 3398/3533: slice_0064.npz ---
# --- Processing file 3399/3533: slice_0078.npz ---
# --- Processing file 3400/3533: slice_0079.npz ---
# --- Processing file 3401/3533: slice_0065.npz ---
# --- Processing file 3402/3533: slice_0075.npz ---
# --- Processing file 3403/3533: slice_0073.npz ---
# --- Processing file 3404/3533: slice_0074.npz ---
# --- Processing file 3405/3533: slice_0072.npz ---
# --- Processing file 3406/3533: slice_0071.npz ---
# --- Processing file 3407/3533: slice_0066.npz ---
# --- Processing file 3408/3533: slice_0076.npz ---
# --- Processing file 3409/3533: slice_0087.npz ---
# --- Processing file 3410/3533: slice_0083.npz ---
# --- Processing file 3411/3533: slice_0091.npz ---
# --- Processing file 3412/3533: slice_0096.npz ---
# --- Processing file 3413/3533: slice_0094.npz ---
# --- Processing file 3414/3533: slice_0098.npz ---
# --- Processing file 3415/3533: slice_0084.npz ---
# --- Processing file 3416/3533: slice_0099.npz ---
# --- Processing file 3417/3533: slice_0085.npz ---
# --- Processing file 3418/3533: slice_0092.npz ---
# --- Processing file 3419/3533: slice_0097.npz ---
# --- Processing file 3420/3533: slice_0088.npz ---
# --- Processing file 3421/3533: slice_0090.npz ---
# --- Processing file 3422/3533: slice_0100.npz ---
# --- Processing file 3423/3533: slice_0080.npz ---
# --- Processing file 3424/3533: slice_0093.npz ---
# --- Processing file 3425/3533: slice_0086.npz ---
# --- Processing file 3426/3533: slice_0081.npz ---
# --- Processing file 3427/3533: slice_0082.npz ---
# --- Processing file 3428/3533: slice_0095.npz ---
# --- Processing file 3429/3533: slice_0089.npz ---
# --- Processing file 3430/3533: slice_0106.npz ---
# --- Processing file 3431/3533: slice_0105.npz ---
# --- Processing file 3432/3533: slice_0101.npz ---
# --- Processing file 3433/3533: slice_0104.npz ---
# --- Processing file 3434/3533: slice_0103.npz ---
# --- Processing file 3435/3533: slice_0102.npz ---
# --- Processing file 3436/3533: slice_0107.npz ---
# --- Processing file 3437/3533: slice_0000.npz ---
# --- Processing file 3438/3533: slice_0013.npz ---
# --- Processing file 3439/3533: slice_0010.npz ---
# --- Processing file 3440/3533: slice_0021.npz ---
# --- Processing file 3441/3533: slice_0011.npz ---
# --- Processing file 3442/3533: slice_0015.npz ---
# --- Processing file 3443/3533: slice_0016.npz ---
# --- Processing file 3444/3533: slice_0014.npz ---
# --- Processing file 3445/3533: slice_0006.npz ---
# --- Processing file 3446/3533: slice_0018.npz ---
# --- Processing file 3447/3533: slice_0009.npz ---
# --- Processing file 3448/3533: slice_0004.npz ---
# --- Processing file 3449/3533: slice_0019.npz ---
# --- Processing file 3450/3533: slice_0020.npz ---
# --- Processing file 3451/3533: slice_0002.npz ---
# --- Processing file 3452/3533: slice_0001.npz ---
# --- Processing file 3453/3533: slice_0005.npz ---
# --- Processing file 3454/3533: slice_0007.npz ---
# --- Processing file 3455/3533: slice_0008.npz ---
# --- Processing file 3456/3533: slice_0003.npz ---
# --- Processing file 3457/3533: slice_0012.npz ---
# --- Processing file 3458/3533: slice_0017.npz ---
# --- Processing file 3459/3533: slice_0031.npz ---
# --- Processing file 3460/3533: slice_0032.npz ---
# --- Processing file 3461/3533: slice_0027.npz ---
# --- Processing file 3462/3533: slice_0024.npz ---
# --- Processing file 3463/3533: slice_0030.npz ---
# --- Processing file 3464/3533: slice_0028.npz ---
# --- Processing file 3465/3533: slice_0029.npz ---
# --- Processing file 3466/3533: slice_0026.npz ---
# --- Processing file 3467/3533: slice_0022.npz ---
# --- Processing file 3468/3533: slice_0023.npz ---
# --- Processing file 3469/3533: slice_0025.npz ---
# --- Processing file 3470/3533: slice_0034.npz ---
# --- Processing file 3471/3533: slice_0037.npz ---
# --- Processing file 3472/3533: slice_0033.npz ---
# --- Processing file 3473/3533: slice_0036.npz ---
# --- Processing file 3474/3533: slice_0039.npz ---
# --- Processing file 3475/3533: slice_0038.npz ---
# --- Processing file 3476/3533: slice_0043.npz ---
# --- Processing file 3477/3533: slice_0040.npz ---
# --- Processing file 3478/3533: slice_0042.npz ---
# --- Processing file 3479/3533: slice_0035.npz ---
# --- Processing file 3480/3533: slice_0041.npz ---
# --- Processing file 3481/3533: slice_0057.npz ---
# --- Processing file 3482/3533: slice_0049.npz ---
# --- Processing file 3483/3533: slice_0056.npz ---
# --- Processing file 3484/3533: slice_0045.npz ---
# --- Processing file 3485/3533: slice_0054.npz ---
# --- Processing file 3486/3533: slice_0047.npz ---
# --- Processing file 3487/3533: slice_0048.npz ---
# --- Processing file 3488/3533: slice_0044.npz ---
# --- Processing file 3489/3533: slice_0055.npz ---
# --- Processing file 3490/3533: slice_0060.npz ---
# --- Processing file 3491/3533: slice_0052.npz ---
# --- Processing file 3492/3533: slice_0061.npz ---
# --- Processing file 3493/3533: slice_0051.npz ---
# --- Processing file 3494/3533: slice_0062.npz ---
# --- Processing file 3495/3533: slice_0053.npz ---
# --- Processing file 3496/3533: slice_0050.npz ---
# --- Processing file 3497/3533: slice_0046.npz ---
# --- Processing file 3498/3533: slice_0058.npz ---
# --- Processing file 3499/3533: slice_0059.npz ---
# --- Processing file 3500/3533: slice_0063.npz ---
# --- Processing file 3501/3533: slice_0083.npz ---
# --- Processing file 3502/3533: slice_0088.npz ---
# --- Processing file 3503/3533: slice_0081.npz ---
# --- Processing file 3504/3533: slice_0076.npz ---
# --- Processing file 3505/3533: slice_0077.npz ---
# --- Processing file 3506/3533: slice_0085.npz ---
# --- Processing file 3507/3533: slice_0072.npz ---
# --- Processing file 3508/3533: slice_0068.npz ---
# --- Processing file 3509/3533: slice_0075.npz ---
# --- Processing file 3510/3533: slice_0079.npz ---
# --- Processing file 3511/3533: slice_0078.npz ---
# --- Processing file 3512/3533: slice_0086.npz ---
# --- Processing file 3513/3533: slice_0067.npz ---
# --- Processing file 3514/3533: slice_0073.npz ---
# --- Processing file 3515/3533: slice_0069.npz ---
# --- Processing file 3516/3533: slice_0080.npz ---
# --- Processing file 3517/3533: slice_0071.npz ---
# --- Processing file 3518/3533: slice_0074.npz ---
# --- Processing file 3519/3533: slice_0084.npz ---
# --- Processing file 3520/3533: slice_0066.npz ---
# --- Processing file 3521/3533: slice_0064.npz ---
# --- Processing file 3522/3533: slice_0082.npz ---
# --- Processing file 3523/3533: slice_0065.npz ---
# --- Processing file 3524/3533: slice_0087.npz ---
# --- Processing file 3525/3533: slice_0070.npz ---
# --- Processing file 3526/3533: slice_0093.npz ---
# --- Processing file 3527/3533: slice_0091.npz ---
# --- Processing file 3528/3533: slice_0095.npz ---
# --- Processing file 3529/3533: slice_0089.npz ---
# --- Processing file 3530/3533: slice_0090.npz ---
# --- Processing file 3531/3533: slice_0092.npz ---
# --- Processing file 3532/3533: slice_0094.npz ---
# --- Processing file 3533/3533: slice_0096.npz ---
#
# 🖼️  All 3533 prediction images have been saved to: /content/drive/MyDrive/dataset-1/Result CNN Test
#
# ✅ Prediction completed successfully!

# %%
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape
        npy_files = list(glob.iglob(os.path.join(folder_path, "", "*.npy"), recursive=True))

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")
        all_images_list = []
        skipped_files = []

        for npy_file in tqdm(npy_files, desc="Loading and processing .npy files"):
            try:
                images = np.load(npy_file)
                original_shape = images.shape
                if len(images.shape) == 2:
                    images = images[None, None, :, :]
                elif len(images.shape) == 3:
                    if images.shape[-1] == 1:
                        images = images[None, :, :, :]
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[-1] == 3:
                        images = images[None, :, :, :]
                        images = np.mean(images, axis=-1, keepdims=True)
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[0] > 1:
                        images = images[:, None, :, :]
                    else:
                        print(f"Skipping {npy_file}: Unexpected 3D shape {original_shape}")
                        skipped_files.append(npy_file)
                        continue
                elif len(images.shape) == 4:
                    if images.shape[1] > 1:
                        if images.shape[1] == 3:
                            images = np.mean(images, axis=1, keepdims=True)
                        elif images.shape[-1] == 3:
                            images = np.mean(images, axis=-1, keepdims=True)
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[-1] == 1:
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[1] == 1:
                            pass
                        else:
                            print(f"Skipping {npy_file}: Unexpected 4D shape with more than 1 channel {images.shape}")
                            skipped_files.append(npy_file)
                            continue
                    elif images.shape[1] == 1:
                        pass
                else:
                    print(f"Skipping {npy_file}: Unexpected shape {original_shape}")
                    skipped_files.append(npy_file)
                    continue

                if len(images.shape) == 4 and images.shape[1:] == self.target_shape:
                    if images.max() > 1.0:
                        images = images.astype(np.float32) / 255.0
                    else:
                        images = images.astype(np.float32)
                    all_images_list.append(images)
                else:
                    print(f"Skipping {npy_file}: Final shape {images.shape} does not match target batch shape (N, {self.target_shape})")
                    skipped_files.append(npy_file)

            except Exception as e:
                print(f"Error loading or processing {npy_file}: {e}")
                skipped_files.append(npy_file)
                continue

        if len(all_images_list) == 0:
            raise ValueError(f"No valid images loaded from {folder_path}. {len(skipped_files)} files were skipped.")

        try:
            self.images = np.concatenate(all_images_list, axis=0)
        except ValueError as e:
            print(f"Error concatenating images: {e}")
            shapes = [img.shape for img in all_images_list]
            print(f"Encountered images with inconsistent shapes during final concat: {shapes}")
            raise ValueError("Images still have inconsistent shapes and cannot be concatenated after filtering.") from e

        print(f"Combined dataset (preloaded): {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")
        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        image = torch.from_numpy(image).float()

        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        return image * 2.0 - 1.0

# --- Main Script ---
# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Dataset and DataLoader setup
folder_path = "/content/drive/MyDrive/dataset-1/all_images_only/all_images_only"
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

# Model configuration
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 256),
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "DownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "UpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Scheduler, Optimizer, Scaler, and Checkpointing
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()
best_loss = float('inf')
train_losses = [] # Initialize train_losses list

# --- Checkpoint Resuming Section ---
# Define a folder in Google Drive to store checkpoints
checkpoint_path = "/content/drive/MyDrive/dataset-1/ddpm_ct_best_model(1).pt"


start_epoch = 0
global_step = 0

if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        best_loss = checkpoint['loss']
        global_step = checkpoint['global_step']
        print(f"✅ Resuming training from epoch {start_epoch}, with best loss {best_loss:.4f}")
    except KeyError:
        # Fallback for old checkpoints that only save the state_dict
        print("⚠ Checkpoint file is not a full dictionary. Attempting to load model state_dict directly.")
        model.load_state_dict(torch.load(checkpoint_path, map_location=device))
        print("✅ Model weights loaded, but training will start from scratch (epoch 0).")
        start_epoch = 0
        global_step = 0
    except Exception as e:
        print(f"❌ Failed to load checkpoint: {e}")
        print("Starting training from scratch.")
        start_epoch = 0
        global_step = 0
else:
    print("No checkpoint found. Starting training from scratch.")
    start_epoch = 0

# Training parameters
num_epochs = start_epoch + 3
accumulation_steps = 4
save_every = 2
log_every = 20

# --- Training Loop ---
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(start_epoch, num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            clear_memory()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1
        train_losses.append(batch_loss) # Append to the losses list

        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1

        if batch_idx % log_every == 0:
            pass

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    # Save best model
    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss, 'global_step': global_step
        }
        torch.save(checkpoint, os.path.join(checkpoint_dir, "ddpm_ct_best_model.pt"))
        print(f"✅ New best model saved to Drive! Loss: {best_loss:.4f}")

    # Save periodic checkpoint
    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss, 'global_step': global_step
        }
        torch.save(checkpoint, os.path.join(checkpoint_dir, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt"))
        print(f"📁 Checkpoint saved to Drive for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

# Save final model state_dict
torch.save(model.state_dict(), os.path.join(checkpoint_dir, "ddpm_ct_final_model.pt"))
print("🎉 Training completed! Final model saved to Drive.")

# Plot training loss
if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

# Test the model with sample generation
print("🖼 Generating test sample...")
model.eval()
with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 100 == 0:
            clear_memory()

    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]

    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved to Drive: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🏁 All done!")
# Out:
# Using device: cpu
# Using device: cpu
# Loading numpy files from folder: /content/drive/MyDrive/dataset-1/all_images_only/all_images_only
# Found 2341 .npy files
# Loading and processing .npy files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Combined dataset (preloaded): 2341 images with shape: (2341, 1, 256, 256)
# Data type: float32, Min: 0.000, Max: 1.000
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /tmp/ipython-input-229766545.py:157: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /usr/local/lib/python3.12/dist-packages/torch/amp/grad_scaler.py:136: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# Loading checkpoint from /content/drive/MyDrive/dataset-1/ddpm_ct_best_model(1).pt...
# ✅ Resuming training from epoch 6, with best loss 0.0200
# Starting training...
# Effective batch size: 32
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch 7/9:   0%|          | 0/292 [00:00<?, ?it/s]
# /tmp/ipython-input-229766545.py:217: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /usr/local/lib/python3.12/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-229766545.py in <cell line: 0>()
#     216
#     217         with autocast():
# --> 218             noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
#     219             loss = F.mse_loss(noise_pred, noise)
#     220             loss = loss / accumulation_steps
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/diffusers/models/unets/unet_2d.py in forward(self, sample, timestep, class_labels, return_dict)
#     335                 sample, skip_sample = upsample_block(sample, res_samples, emb, skip_sample)
#     336             else:
# --> 337                 sample = upsample_block(sample, res_samples, emb)
#     338
#     339         # 6. post-process
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/diffusers/models/unets/unet_2d_blocks.py in forward(self, hidden_states, res_hidden_states_tuple, temb, upsample_size, *args, **kwargs)
#    2300             else:
#    2301                 hidden_states = resnet(hidden_states, temb)
# -> 2302                 hidden_states = attn(hidden_states)
#    2303
#    2304         if self.upsamplers is not None:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/diffusers/models/attention_processor.py in forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     603         cross_attention_kwargs = {k: w for k, w in cross_attention_kwargs.items() if k in attn_parameters}
#     604
# --> 605         return self.processor(
#     606             self,
#     607             hidden_states,
#
# /usr/local/lib/python3.12/dist-packages/diffusers/models/attention_processor.py in __call__(self, attn, hidden_states, encoder_hidden_states, attention_mask, temb, *args, **kwargs)
#    2763         # the output of sdp = (batch, num_heads, seq_len, head_dim)
#    2764         # TODO: add support for attn.scale when we move to Torch 2.1
# -> 2765         hidden_states = F.scaled_dot_product_attention(
#    2766             query, key, value, attn_mask=attention_mask, dropout_p=0.0, is_causal=False
#    2767         )
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler, DDIMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# --- 1. Utility Functions ---
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# --- 2. Dataset Class ---
class MultipleNumpyDataset(Dataset):
    """Handles loading and preprocessing of multiple .npy files."""
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape
        npy_files = list(glob.iglob(os.path.join(folder_path, "**", "*.npy"), recursive=True))

        if not npy_files:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")
        all_images_list = []

        for npy_file in tqdm(npy_files, desc="Processing files"):
            try:
                images = np.load(npy_file)
                if len(images.shape) == 2:
                    images = images[None, None, :, :]
                elif len(images.shape) == 3:
                    if images.shape[0] > 1:
                        images = images[:, None, :, :]
                    else:
                        images = np.transpose(images[None, :, :, :], (0, 3, 1, 2))
                elif len(images.shape) == 4 and images.shape[1] > 1:
                    if images.shape[1] == 3:
                        images = np.mean(images, axis=1, keepdims=True)
                    else:
                        continue
                elif len(images.shape) == 4 and images.shape[-1] > 1:
                    images = np.mean(images, axis=-1, keepdims=True)
                    images = np.transpose(images, (0, 3, 1, 2))

                if images.max() > 1.0:
                    images = images.astype(np.float32) / 255.0
                else:
                    images = images.astype(np.float32)

                if images.shape[1:] == self.target_shape:
                    all_images_list.append(images)
            except Exception as e:
                print(f"Error processing {npy_file}: {e}")

        if not all_images_list:
            raise ValueError("No valid images loaded after processing.")

        self.images = np.concatenate(all_images_list, axis=0)
        print(f"Final combined dataset size: {len(self.images)} images")

        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        image = torch.from_numpy(image).float()

        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        return image * 2.0 - 1.0

# --- 3. Main Script ---
# Dataset and DataLoader setup
folder_path = "/content/drive/MyDrive/dataset-1/all_images_only/all_images_only"
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

# Model configuration
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 512),
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "AttnDownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "AttnUpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Scheduler, Optimizer, Scaler, and Checkpointing
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()
best_loss = float('inf')
train_losses = []

# Checkpoint Resuming Section
checkpoint_dir = "/content/checkpoints" # Local Colab path
os.makedirs(checkpoint_dir, exist_ok=True)
checkpoint_path = os.path.join(checkpoint_dir, "/content/ddpm_ct_best_model (1) (1).pt")

if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    best_loss = checkpoint['loss']
    global_step = checkpoint['global_step']
    print(f"Resuming training from epoch {start_epoch}")
else:
    print("No checkpoint found. Starting training from scratch.")
    start_epoch = 0
    global_step = 0

# Training parameters
num_epochs = start_epoch + 3
accumulation_steps = 4
save_every = 2
log_every = 20

# --- 4. Training Loop ---
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(start_epoch, num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            clear_memory()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1

        if batch_idx % log_every == 0:
            pass

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss, 'global_step': global_step
        }
        torch.save(checkpoint, os.path.join(checkpoint_dir, "ddpm_ct_best_model.pt"))
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss, 'global_step': global_step
        }
        torch.save(checkpoint, os.path.join(checkpoint_dir, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt"))
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

torch.save(model.state_dict(), os.path.join(checkpoint_dir, "ddpm_ct_final_model.pt"))
print("🎉 Training completed!")

# --- 5. Inference Section ---
print("🖼️ Generating test sample...")
model.eval()
ddim_scheduler = DDIMScheduler.from_config(model.config)
ddim_scheduler.set_timesteps(num_inference_steps=50)

with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)

    for i, t in enumerate(tqdm(ddim_scheduler.timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = ddim_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 10 == 0: clear_memory()

    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]

    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()
    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print(f"• Models saved to Colab: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🏁 All done!")
# Out:
# Using device: cuda
# Loading numpy files from folder: /content/drive/MyDrive/dataset-1/all_images_only/all_images_only
# Found 2341 .npy files
# Processing files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Final combined dataset size: 2341 images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /tmp/ipython-input-1281727803.py:118: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Loading checkpoint from /content/ddpm_ct_best_model (1) (1).pt...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1281727803.py in <cell line: 0>()
#     128     print(f"Loading checkpoint from {checkpoint_path}...")
#     129     checkpoint = torch.load(checkpoint_path, map_location=device)
# --> 130     model.load_state_dict(checkpoint['model_state_dict'])
#     131     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     132     scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2622
#    2623         if len(error_msgs) > 0:
# -> 2624             raise RuntimeError(
#    2625                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2626                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for UNet2DModel:
# 	Missing key(s) in state_dict: "down_blocks.2.attentions.0.group_norm.weight", "down_blocks.2.attentions.0.group_norm.bias", "down_blocks.2.attentions.0.to_q.weight", "down_blocks.2.attentions.0.to_q.bias", "down_blocks.2.attentions.0.to_k.weight", "down_blocks.2.attentions.0.to_k.bias", "down_blocks.2.attentions.0.to_v.weight", "down_blocks.2.attentions.0.to_v.bias", "down_blocks.2.attentions.0.to_out.0.weight", "down_blocks.2.attentions.0.to_out.0.bias", "down_blocks.2.attentions.1.group_norm.weight", "down_blocks.2.attentions.1.group_norm.bias", "down_blocks.2.attentions.1.to_q.weight", "down_blocks.2.attentions.1.to_q.bias", "down_blocks.2.attentions.1.to_k.weight", "down_blocks.2.attentions.1.to_k.bias", "down_blocks.2.attentions.1.to_v.weight", "down_blocks.2.attentions.1.to_v.bias", "down_blocks.2.attentions.1.to_out.0.weight", "down_blocks.2.attentions.1.to_out.0.bias", "down_blocks.3.resnets.0.conv_shortcut.weight", "down_blocks.3.resnets.0.conv_shortcut.bias", "up_blocks.2.attentions.0.group_norm.weight", "up_blocks.2.attentions.0.group_norm.bias", "up_blocks.2.attentions.0.to_q.weight", "up_blocks.2.attentions.0.to_q.bias", "up_blocks.2.attentions.0.to_k.weight", "up_blocks.2.attentions.0.to_k.bias", "up_blocks.2.attentions.0.to_v.weight", "up_blocks.2.attentions.0.to_v.bias", "up_blocks.2.attentions.0.to_out.0.weight", "up_blocks.2.attentions.0.to_out.0.bias", "up_blocks.2.attentions.1.group_norm.weight", "up_blocks.2.attentions.1.group_norm.bias", "up_blocks.2...
# 	size mismatch for down_blocks.3.resnets.0.conv1.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 256, 3, 3]).
# 	size mismatch for down_blocks.3.resnets.0.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.0.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for down_blocks.3.resnets.0.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.0.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.0.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.0.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for down_blocks.3.resnets.0.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.norm1.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.norm1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.conv1.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for down_blocks.3.resnets.1.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for down_blocks.3.resnets.1.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for down_blocks.3.resnets.1.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for down_blocks.3.resnets.1.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.norm1.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for up_blocks.0.resnets.0.norm1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for up_blocks.0.resnets.0.conv1.weight: copying a param with shape torch.Size([256, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 1024, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.0.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for up_blocks.0.resnets.0.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.0.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.0.conv_shortcut.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 1024, 1, 1]).
# 	size mismatch for up_blocks.0.resnets.0.conv_shortcut.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.norm1.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for up_blocks.0.resnets.1.norm1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for up_blocks.0.resnets.1.conv1.weight: copying a param with shape torch.Size([256, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 1024, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.1.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for up_blocks.0.resnets.1.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.1.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.1.conv_shortcut.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 1024, 1, 1]).
# 	size mismatch for up_blocks.0.resnets.1.conv_shortcut.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.norm1.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([768]).
# 	size mismatch for up_blocks.0.resnets.2.norm1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([768]).
# 	size mismatch for up_blocks.0.resnets.2.conv1.weight: copying a param with shape torch.Size([256, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 768, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.2.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for up_blocks.0.resnets.2.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for up_blocks.0.resnets.2.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.resnets.2.conv_shortcut.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 768, 1, 1]).
# 	size mismatch for up_blocks.0.resnets.2.conv_shortcut.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.0.upsamplers.0.conv.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for up_blocks.0.upsamplers.0.conv.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for up_blocks.1.resnets.0.norm1.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([768]).
# 	size mismatch for up_blocks.1.resnets.0.norm1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([768]).
# 	size mismatch for up_blocks.1.resnets.0.conv1.weight: copying a param with shape torch.Size([256, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 768, 3, 3]).
# 	size mismatch for up_blocks.1.resnets.0.conv_shortcut.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 768, 1, 1]).
# 	size mismatch for mid_block.attentions.0.group_norm.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.attentions.0.group_norm.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.attentions.0.to_q.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 512]).
# 	size mismatch for mid_block.attentions.0.to_q.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.attentions.0.to_k.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 512]).
# 	size mismatch for mid_block.attentions.0.to_k.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.attentions.0.to_v.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 512]).
# 	size mismatch for mid_block.attentions.0.to_v.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.attentions.0.to_out.0.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 512]).
# 	size mismatch for mid_block.attentions.0.to_out.0.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.norm1.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.norm1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.conv1.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for mid_block.resnets.0.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for mid_block.resnets.0.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.0.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for mid_block.resnets.0.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.norm1.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.norm1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.conv1.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for mid_block.resnets.1.conv1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.time_emb_proj.weight: copying a param with shape torch.Size([256, 256]) from checkpoint, the shape in current model is torch.Size([512, 256]).
# 	size mismatch for mid_block.resnets.1.time_emb_proj.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.norm2.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.norm2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for mid_block.resnets.1.conv2.weight: copying a param with shape torch.Size([256, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for mid_block.resnets.1.conv2.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).

# %%
import torch
import torch.nn.functional as F
from diffusers import UNet2DModel, DDPMScheduler
from torch.utils.data import DataLoader, Dataset
from tqdm.auto import tqdm
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler
import matplotlib.pyplot as plt
import os
import glob

# Memory management for Colab
def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Updated Dataset class for multiple numpy files in a folder
class MultipleNumpyDataset(Dataset):
    def __init__(self, folder_path, augment=True, target_shape=(1, 256, 256)):
        print(f"Loading numpy files from folder: {folder_path}")
        self.target_shape = target_shape
        npy_files = list(glob.iglob(os.path.join(folder_path, "**", "*.npy"), recursive=True))

        if len(npy_files) == 0:
            raise ValueError(f"No .npy files found recursively in {folder_path}")

        print(f"Found {len(npy_files)} .npy files")
        all_images_list = []
        skipped_files = []

        for npy_file in tqdm(npy_files, desc="Loading and processing .npy files"):
            try:
                images = np.load(npy_file)
                original_shape = images.shape
                if len(images.shape) == 2:
                    images = images[None, None, :, :]
                elif len(images.shape) == 3:
                    if images.shape[-1] == 1:
                        images = images[None, :, :, :]
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[-1] == 3:
                        images = images[None, :, :, :]
                        images = np.mean(images, axis=-1, keepdims=True)
                        images = np.transpose(images, (0, 3, 1, 2))
                    elif images.shape[0] > 1:
                        images = images[:, None, :, :]
                    else:
                        print(f"Skipping {npy_file}: Unexpected 3D shape {original_shape}")
                        skipped_files.append(npy_file)
                        continue
                elif len(images.shape) == 4:
                    if images.shape[1] > 1:
                        if images.shape[1] == 3:
                            images = np.mean(images, axis=1, keepdims=True)
                        elif images.shape[-1] == 3:
                            images = np.mean(images, axis=-1, keepdims=True)
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[-1] == 1:
                            images = np.transpose(images, (0, 3, 1, 2))
                        elif images.shape[1] == 1:
                            pass
                        else:
                            print(f"Skipping {npy_file}: Unexpected 4D shape with more than 1 channel {images.shape}")
                            skipped_files.append(npy_file)
                            continue
                    elif images.shape[1] == 1:
                        pass
                else:
                    print(f"Skipping {npy_file}: Unexpected shape {original_shape}")
                    skipped_files.append(npy_file)
                    continue

                if len(images.shape) == 4 and images.shape[1:] == self.target_shape:
                    if images.max() > 1.0:
                        images = images.astype(np.float32) / 255.0
                    else:
                        images = images.astype(np.float32)
                    all_images_list.append(images)
                else:
                    print(f"Skipping {npy_file}: Final shape {images.shape} does not match target batch shape (N, {self.target_shape})")
                    skipped_files.append(npy_file)

            except Exception as e:
                print(f"Error loading or processing {npy_file}: {e}")
                skipped_files.append(npy_file)
                continue

        if len(all_images_list) == 0:
            raise ValueError(f"No valid images loaded from {folder_path}. {len(skipped_files)} files were skipped.")

        try:
            self.images = np.concatenate(all_images_list, axis=0)
        except ValueError as e:
            print(f"Error concatenating images: {e}")
            shapes = [img.shape for img in all_images_list]
            print(f"Encountered images with inconsistent shapes during final concat: {shapes}")
            raise ValueError("Images still have inconsistent shapes and cannot be concatenated after filtering.") from e

        print(f"Combined dataset (preloaded): {self.images.shape[0]} images with shape: {self.images.shape}")
        print(f"Data type: {self.images.dtype}, Min: {self.images.min():.3f}, Max: {self.images.max():.3f}")
        self.augment = augment

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx].copy()
        image = torch.from_numpy(image).float()

        if self.augment and np.random.random() > 0.5:
            if np.random.random() > 0.5:
                image = torch.flip(image, [2])

        return image * 2.0 - 1.0

# --- Main Script ---
# Set the device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Dataset and DataLoader setup
folder_path = '/content/drive/MyDrive/dataset-1/all_images_only/all_images_only'
train_dataset = MultipleNumpyDataset(folder_path, augment=True)
train_dataloader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True,
    persistent_workers=True
)

# Model configuration
model = UNet2DModel(
    sample_size=256,
    in_channels=1,
    out_channels=1,
    layers_per_block=2,
    block_out_channels=(64, 128, 256, 256),
    down_block_types=("DownBlock2D", "AttnDownBlock2D", "DownBlock2D", "DownBlock2D"),
    up_block_types=("UpBlock2D", "AttnUpBlock2D", "UpBlock2D", "UpBlock2D"),
    attention_head_dim=8,
)
model.to(device)

# Scheduler, Optimizer, Scaler, and Checkpointing
noise_scheduler = DDPMScheduler(num_train_timesteps=1000)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
scaler = GradScaler()
best_loss = float('inf')

# --- Checkpoint Resuming Section ---
checkpoint_path = "/content/ddpm_ct_best_model (1) (1).pt"
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    best_loss = checkpoint['loss']
    print(f"Resuming training from epoch {start_epoch}")
else:
    print("No checkpoint found. Starting training from scratch.")
    start_epoch = 0

# Training parameters
num_epochs = start_epoch + 3
accumulation_steps = 4
save_every = 2
log_every = 20
global_step = checkpoint['global_step'] if os.path.exists(checkpoint_path) and 'global_step' in checkpoint else 0

# --- Training Loop ---
print("Starting training...")
print(f"Effective batch size: {train_dataloader.batch_size * accumulation_steps}")

for epoch in range(start_epoch, num_epochs):
    model.train()
    epoch_loss = 0.0
    num_batches = 0
    progress_bar = tqdm(enumerate(train_dataloader), total=len(train_dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch_idx, batch in progress_bar:
        clean_images = batch.to(device, non_blocking=True)
        timesteps = torch.randint(0, noise_scheduler.config.num_train_timesteps, (clean_images.shape[0],), device=device).long()
        noise = torch.randn_like(clean_images)
        noisy_images = noise_scheduler.add_noise(clean_images, noise, timesteps)

        with autocast():
            noise_pred = model(noisy_images, timesteps, return_dict=False)[0]
            loss = F.mse_loss(noise_pred, noise)
            loss = loss / accumulation_steps

        scaler.scale(loss).backward()

        if (batch_idx + 1) % accumulation_steps == 0 or batch_idx == len(train_dataloader) - 1:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()
            clear_memory()

        batch_loss = loss.item() * accumulation_steps
        epoch_loss += batch_loss
        num_batches += 1

        current_lr = optimizer.param_groups[0]['lr']
        progress_bar.set_postfix({
            'loss': f"{batch_loss:.4f}",
            'avg_loss': f"{epoch_loss / num_batches:.4f}",
            'lr': f"{current_lr:.6f}",
            'step': global_step
        })
        global_step += 1

        if batch_idx % log_every == 0:
            pass

    avg_epoch_loss = epoch_loss / num_batches
    scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs} completed.")
    print(f"Average loss: {avg_epoch_loss:.4f}")

    if avg_epoch_loss < best_loss:
        best_loss = avg_epoch_loss
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': best_loss, 'global_step': global_step
        }
        torch.save(checkpoint, "ddpm_ct_best_model.pt")
        print(f"✅ New best model saved! Loss: {best_loss:.4f}")

    if (epoch + 1) % save_every == 0:
        checkpoint = {
            'epoch': epoch, 'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(), 'scheduler_state_dict': scheduler.state_dict(),
            'loss': avg_epoch_loss, 'global_step': global_step
        }
        torch.save(checkpoint, f"ddpm_ct_checkpoint_epoch_{epoch+1}.pt")
        print(f"📁 Checkpoint saved for epoch {epoch+1}")

    if torch.cuda.is_available():
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"GPU Memory: {allocated:.2f}GB allocated, {reserved:.2f}GB reserved")

    clear_memory()

torch.save(model.state_dict(), "ddpm_ct_final_model.pt")
print("🎉 Training completed!")

# Plot training loss
if train_losses:
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses)
    plt.title('Training Loss')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.grid(True)
    plt.savefig('training_loss.png', dpi=150, bbox_inches='tight')
    plt.show()

# Test the model with sample generation
print("🖼️  Generating test sample...")
model.eval()
with torch.no_grad():
    sample_shape = (1, 1, 256, 256)
    sample = torch.randn(sample_shape, device=device)
    timesteps = noise_scheduler.timesteps
    for i, t in enumerate(tqdm(timesteps, desc="Denoising")):
        with autocast():
            noise_pred = model(sample, t.unsqueeze(0).to(device), return_dict=False)[0]
        sample = noise_scheduler.step(noise_pred, t, sample).prev_sample
        if i % 100 == 0:
            clear_memory()

    sample = (sample + 1) / 2
    sample = torch.clamp(sample, 0, 1)
    sample_np = sample.cpu().numpy()[0, 0]

    plt.figure(figsize=(8, 8))
    plt.imshow(sample_np, cmap='gray')
    plt.title('Generated CT Scan Sample')
    plt.axis('off')
    plt.savefig('generated_ct_sample.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✅ Sample saved as 'generated_ct_sample.png'")

print("\n📋 Training Summary:")
print(f"• Dataset size: {len(train_dataset):,} images")
print(f"• Image resolution: 256×256")
print(f"• Total epochs: {num_epochs}")
print(f"• Best loss: {best_loss:.4f}")
print(f"• Total training steps: {global_step:,}")
print("• Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt")
print("\n🏁 All done!")
# Out:
# Using device: cuda
# Using device: cuda
# Loading numpy files from folder: /content/drive/MyDrive/dataset-1/all_images_only/all_images_only
# Found 2341 .npy files
# Loading and processing .npy files:   0%|          | 0/2341 [00:00<?, ?it/s]
# Combined dataset (preloaded): 2341 images with shape: (2341, 1, 256, 256)
# Data type: float32, Min: 0.000, Max: 1.000
# /tmp/ipython-input-921647548.py:157: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Loading checkpoint from /content/ddpm_ct_best_model (1) (1).pt...
# Resuming training from epoch 6
# Starting training...
# Effective batch size: 32
# Epoch 7/9:   0%|          | 0/292 [00:00<?, ?it/s]
# /tmp/ipython-input-921647548.py:198: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 7/9 completed.
# Average loss: 0.0221
# GPU Memory: 1.01GB allocated, 1.35GB reserved
# Epoch 8/9:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 8/9 completed.
# Average loss: 0.0200
# 📁 Checkpoint saved for epoch 8
# GPU Memory: 0.91GB allocated, 1.38GB reserved
# Epoch 9/9:   0%|          | 0/292 [00:00<?, ?it/s]
# Epoch 9/9 completed.
# Average loss: 0.0175
# ✅ New best model saved! Loss: 0.0175
# GPU Memory: 0.91GB allocated, 1.28GB reserved
# 🎉 Training completed!
# 🖼️  Generating test sample...
# Denoising:   0%|          | 0/1000 [00:00<?, ?it/s]
# /tmp/ipython-input-921647548.py:284: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ✅ Sample saved as 'generated_ct_sample.png'
#
# 📋 Training Summary:
# • Dataset size: 2,341 images
# • Image resolution: 256×256
# • Total epochs: 9
# • Best loss: 0.0175
# • Total training steps: 2,628
# • Models saved: ddpm_ct_best_model.pt, ddpm_ct_final_model.pt
#
# 🏁 All done!

# %%
import torch
print(torch.__version__)
# Out:
# 2.8.0+cu126
